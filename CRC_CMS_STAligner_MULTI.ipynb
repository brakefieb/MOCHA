# %% [markdown]
# # Imports

# %%
# =============================================================================
# Imports and environment setup
# =============================================================================
import os
import sys
import time
import logging
import warnings
import tempfile
from pathlib import Path

warnings.filterwarnings("ignore")

# Make the kernel robust if launched through VSCode/Jupyter rather than
# from an already activated conda shell.
CONDA_PREFIX = Path(sys.executable).resolve().parents[1]

# Juno STAligner environment paths fixed during installation.
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["CUDA_HOME"] = "/opt/ohpc/pub/apps/cuda/11.7"
os.environ["STALIGNER_CUDA_LIB"] = "/opt/ohpc/pub/apps/cuda/11.7/targets/x86_64-linux/lib"
os.environ["R_HOME"] = str(CONDA_PREFIX / "lib" / "R")
os.environ.pop("R_USER", None)
os.environ["PYTHONNOUSERSITE"] = "1"

# Make conda, R, and CUDA runtime libraries preferred inside Jupyter.
os.environ["LD_LIBRARY_PATH"] = (
    f"{CONDA_PREFIX}/lib:"
    f"{CONDA_PREFIX}/lib/R/lib:"
    f"{os.environ['STALIGNER_CUDA_LIB']}:"
    + os.environ.get("LD_LIBRARY_PATH", "")
)

print("Python:", sys.executable)
print("CONDA_PREFIX:", CONDA_PREFIX)
print("CUDA_HOME:", os.environ.get("CUDA_HOME"))
print("R_HOME:", os.environ.get("R_HOME"))
print("LD_LIBRARY_PATH first:", os.environ.get("LD_LIBRARY_PATH", "").split(":")[0])

import h5py
import numpy as np
import pandas as pd
import scipy
import scipy.sparse as sp
import scanpy as sc
import anndata as ad
import torch

from sklearn import metrics as sk_metrics

import rpy2
import rpy2.robjects as ro

import STAligner

print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("scipy:", scipy.__version__)
print("scanpy:", sc.__version__)
print("anndata:", ad.__version__)
print("torch:", torch.__version__, "cuda available:", torch.cuda.is_available(), "torch cuda:", torch.version.cuda)
if torch.cuda.is_available():
    print("gpu:", torch.cuda.get_device_name(0))
print("rpy2:", rpy2.__version__)
print("STAligner:", STAligner.__file__)
# Out:
# Python: /work/dal875013/conda_envs/staligner_env/bin/python
# CONDA_PREFIX: /work/dal875013/conda_envs/staligner_env
# CUDA_HOME: /opt/ohpc/pub/apps/cuda/11.7
# R_HOME: /work/dal875013/conda_envs/staligner_env/lib/R
# LD_LIBRARY_PATH first: /work/dal875013/conda_envs/staligner_env/lib
# numpy: 1.20.3
# pandas: 1.2.3
# scipy: 1.5.3
# scanpy: 1.9.1
# anndata: 0.7.8
# torch: 1.9.1+cu111 cuda available: True torch cuda: 11.1
# gpu: NVIDIA A30
# rpy2: 3.5.16
# STAligner: /work/dal875013/projects/mocha/methods/STAligner/STAligner/__init__.py

# %% [markdown]
# # USER CONFIGURATION — edit these to match your environment

# %%
# =============================================================================
# USER CONFIGURATION
# =============================================================================

# Path to cloned STAligner repo
STALIGNER_ROOT = Path(r"/work/dal875013/projects/mocha/methods/STAligner")

# Path to the folder containing CRC_CMS SCE_*.h5ad files
DATA_ROOT = Path(r"/groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data")

# Output folder for parquet results
OUTPUT_DIR = Path(r"/home/dal875013/work/projects/mocha/results/STAligner/crc_cms_STAligner")

# Subject-level CRC_CMS grouping from the dataset README.
# Each subject has two replicate spatial transcriptomics samples.
CRC_CMS_SUBJECT_GROUPS = {
    "subject_1": ["SN048_A121573_Rep1", "SN048_A121573_Rep2"],
    "subject_2": ["SN048_A416371_Rep1", "SN048_A416371_Rep2"],
    "subject_3": ["SN123_A551763_Rep1", "SN124_A551763_Rep2"],
    "subject_4": ["SN123_A595688_Rep1", "SN124_A595688_Rep2"],
    "subject_5": ["SN123_A798015_Rep1", "SN124_A798015_Rep2"],
    "subject_6": ["SN123_A938797_Rep1_X", "SN124_A938797_Rep2"],
    "subject_7": ["SN84_A120838_Rep1", "SN84_A120838_Rep2"],
}

# ----- SUBSET SELECTOR -----------------------------------------------------
# First smoke test:
# SUBJECT_GROUPS_TO_RUN = "subject_7"
#
# Full run:
SUBJECT_GROUPS_TO_RUN = None
#
# You can also use:
# SUBJECT_GROUPS_TO_RUN = ["subject_1", "subject_7"]

METHOD_NAME = "STAligner"
CLUST_METHOD = "mclust"
NUM_RUNS = 1

# CRC_CMS benchmark uses fixed 6 spatial domains.
FIXED_NUM_CLUSTERS = 6

# Ground-truth label column in adata.obs.
GT_LABEL_COL = None

# STAligner parameters adapted from the DLPFC tutorial benchmark style.
RAD_CUTOFF = 150
N_TOP_GENES = 5000
KNN_NEIGH = 50


# =============================================================================
# General helpers
# =============================================================================
def setup_logging(output_dir: Path):
    output_dir.mkdir(parents=True, exist_ok=True)
    log_file = output_dir / "benchmark.log"
    logging.basicConfig(
        level=logging.INFO,
        format="%(asctime)s [%(levelname)s] %(message)s",
        handlers=[
            logging.StreamHandler(sys.stdout),
            logging.FileHandler(log_file, mode="w"),
        ],
        force=True,
    )
    logging.info(f"Log file: {log_file}")


def get_device():
    """Return torch.device('cuda:0') if a CUDA GPU is available, else CPU. Logs details."""
    if torch.cuda.is_available():
        dev = torch.device("cuda:0")
        os.environ["CUDA_VISIBLE_DEVICES"] = "0"
        logging.info(f"[DEVICE] CUDA available — using {dev}")
        logging.info(f"[DEVICE] GPU name: {torch.cuda.get_device_name(0)}")
        logging.info(
            f"[DEVICE] GPU memory: "
            f"{torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB"
        )
    else:
        dev = torch.device("cpu")
        logging.warning("[DEVICE] No CUDA GPU detected — falling back to CPU")
    return dev


def resolve_subject_groups(selector) -> dict:
    """Turn SUBJECT_GROUPS_TO_RUN into a concrete dict: subject_name -> sample_ids."""
    if selector is None or selector == "all":
        return dict(CRC_CMS_SUBJECT_GROUPS)
    if isinstance(selector, str):
        return {selector: CRC_CMS_SUBJECT_GROUPS[selector]}
    if isinstance(selector, (list, tuple)):
        return {name: CRC_CMS_SUBJECT_GROUPS[name] for name in selector}
    raise ValueError(f"Unrecognized SUBJECT_GROUPS_TO_RUN value: {selector!r}")


def detect_gt_column(adata) -> str:
    """Auto-detect which obs column holds the ground-truth layer label."""
    if GT_LABEL_COL is not None:
        if GT_LABEL_COL not in adata.obs.columns:
            raise KeyError(
                f"GT_LABEL_COL={GT_LABEL_COL!r} not in adata.obs. "
                f"Available columns: {list(adata.obs.columns)}"
            )
        return GT_LABEL_COL

    candidates = [
        "layer_guess", "layer_guess_reordered", "layer_guess_reordered_short",
        "Ground Truth", "ground_truth", "GroundTruth",
        "layer", "Layer", "annotation", "Annotation", "z",
    ]
    for c in candidates:
        if c in adata.obs.columns:
            return c
    raise KeyError(
        f"Could not auto-detect ground-truth column. "
        f"adata.obs columns: {list(adata.obs.columns)}. "
        f"Please set GT_LABEL_COL manually."
    )


def ensure_spatial_obsm(adata, sample_id: str):
    """Ensure adata.obsm['spatial'] exists for STAligner.Cal_Spatial_Net and plotting."""
    if "spatial" in adata.obsm:
        adata.obsm["spatial"] = np.asarray(adata.obsm["spatial"]).astype(float)
        return
    if "S" in adata.obsm:
        adata.obsm["spatial"] = np.asarray(adata.obsm["S"]).astype(float)
        logging.info(f"    [DIAG] {sample_id}: aliased obsm['S'] -> obsm['spatial']")
        return
    xy_candidates = [
        ("x", "y"), ("X", "Y"),
        ("spatial_x", "spatial_y"),
        ("array_col", "array_row"),
        ("pxl_col_in_fullres", "pxl_row_in_fullres"),
        ("imagecol", "imagerow"),
    ]
    for xcol, ycol in xy_candidates:
        if xcol in adata.obs.columns and ycol in adata.obs.columns:
            adata.obsm["spatial"] = adata.obs[[xcol, ycol]].to_numpy(dtype=float)
            logging.info(f"    [DIAG] {sample_id}: created obsm['spatial'] from {xcol}, {ycol}")
            return
    raise KeyError(
        f"{sample_id}: cannot find spatial coordinates. "
        f"Available obsm keys={list(adata.obsm.keys())}, obs columns={list(adata.obs.columns)}"
    )


def clean_label_mask(labels) -> np.ndarray:
    """Keep labeled spots and drop NA/unknown labels."""
    s = pd.Series(labels).astype(object)
    not_na = ~pd.isnull(s)
    lower = s.astype(str).str.lower()
    known = ~lower.isin(["unknown", "nan", "none", "na", ""])
    return (not_na & known).to_numpy()


def get_num_clusters() -> int:
    """Return fixed number of CRC_CMS clusters."""
    return int(FIXED_NUM_CLUSTERS)


def check_mclust_if_needed():
    """Fail early if mclust clustering is requested but unavailable."""
    if CLUST_METHOD != "mclust":
        return
    try:
        ro.r("library(mclust)")
        logging.info("[CHECK] R package mclust is available")
    except Exception as e:
        raise RuntimeError(
            "Cannot load R package 'mclust'. In staligner_env, run:\n"
            "conda install -n staligner_env -c conda-forge r-mclust -y\n"
            "or install it inside R.\n"
            f"Original error: {e}"
        )


def check_parquet_support():
    """Fail before training if pandas cannot write parquet output."""
    try:
        import pyarrow as pa
        logging.info(f"[CHECK] pyarrow is available: {pa.__version__}")
        return
    except Exception:
        pass
    try:
        import fastparquet  # noqa: F401
        logging.info("[CHECK] fastparquet is available")
        return
    except Exception:
        pass
    raise RuntimeError(
        "Parquet support is missing. Install one parquet engine in staligner_env before running:\n"
        "/work/dal875013/conda_envs/staligner_env/bin/python -m pip install --no-cache-dir --only-binary=:all: pyarrow==10.0.1"
    )


def save_table(df: pd.DataFrame, path_base: Path) -> Path:
    """Save a table as parquet only."""
    parquet_path = path_base.with_suffix(".parquet")
    df.to_parquet(parquet_path, index=False)
    return parquet_path


def read_saved_table(path_base: Path) -> pd.DataFrame:
    """Read a parquet table saved by this notebook."""
    parquet_path = path_base.with_suffix(".parquet")
    if not parquet_path.exists():
        raise FileNotFoundError(f"Cannot find {parquet_path}")
    return pd.read_parquet(parquet_path)

# %% [markdown]
# # Data loading  (adapted for .h5ad input)

# %%
# =============================================================================
# Data loading  (adapted for new-format .h5ad input with old anndata)
# =============================================================================
# Why this cell is more complicated:
# The STAligner environment intentionally uses old scanpy/anndata versions.
# The QuickSRT h5ad files were written by newer anndata, so sc.read_h5ad may fail
# at newer-encoded groups such as /layers or /obs/z. STAligner only needs X,
# obs labels, var names, and spatial coordinates. The fallback below uses h5py
# to read only those pieces and construct a minimal AnnData object.


def _decode_scalar(x):
    """Decode bytes-like scalar values to str; keep numeric values unchanged."""
    if isinstance(x, bytes):
        return x.decode("utf-8")
    if isinstance(x, np.bytes_):
        return x.astype(str).item()
    return x


def _decode_array(arr):
    """Decode byte string arrays from h5py into normal numpy arrays of str/object."""
    arr = np.asarray(arr)
    if arr.dtype.kind == "S":
        return arr.astype(str)
    if arr.dtype.kind == "O":
        return np.asarray([_decode_scalar(x) for x in arr], dtype=object)
    return arr


def _decode_attr(x):
    """Decode h5py attributes, including arrays of bytes."""
    if x is None:
        return None
    if isinstance(x, (list, tuple)):
        return [_decode_scalar(v) for v in x]
    if isinstance(x, np.ndarray):
        return [_decode_scalar(v) for v in x.tolist()]
    return _decode_scalar(x)


def _h5_node_summary(node) -> str:
    keys = list(node.keys()) if isinstance(node, h5py.Group) else []
    attrs = {str(k): _decode_attr(v) for k, v in getattr(node, "attrs", {}).items()}
    shape = getattr(node, "shape", None)
    dtype = getattr(node, "dtype", None)
    return f"type={type(node).__name__}, shape={shape}, dtype={dtype}, keys={keys[:10]}, attrs={attrs}"


def _read_h5_dataset(node):
    """Read a plain HDF5 dataset and decode byte strings."""
    arr = node[()]
    if isinstance(arr, bytes):
        return arr.decode("utf-8")
    return _decode_array(arr)


def _read_h5_vector(node):
    """
    Read a 1D vector-like h5ad element.
    Handles old/new categorical encodings and several simple wrappers.
    """
    if isinstance(node, h5py.Dataset):
        arr = _read_h5_dataset(node)
        return np.asarray(arr)

    if not isinstance(node, h5py.Group):
        raise TypeError(f"Unsupported HDF5 node: {type(node)}")

    keys = set(node.keys())

    if {"codes", "categories"}.issubset(keys):
        codes = np.asarray(_read_h5_vector(node["codes"])).astype(int)
        categories = np.asarray(_read_h5_vector(node["categories"]), dtype=object)
        out = np.empty(len(codes), dtype=object)
        out[:] = np.nan
        valid = codes >= 0
        out[valid] = categories[codes[valid]]
        return out

    for key in ["values", "value", "data", "array"]:
        if key in keys:
            try:
                return np.asarray(_read_h5_vector(node[key]))
            except Exception:
                pass

    if len(keys) == 1:
        only_key = next(iter(keys))
        return np.asarray(_read_h5_vector(node[only_key]))

    raise ValueError(f"Cannot read vector from HDF5 group: {_h5_node_summary(node)}")


def _read_h5_matrix(node):
    """Read dense or sparse matrix-like h5ad elements."""
    if isinstance(node, h5py.Dataset):
        return _read_h5_dataset(node)

    if not isinstance(node, h5py.Group):
        raise TypeError(f"Unsupported HDF5 node: {type(node)}")

    keys = set(node.keys())
    encoding_type = _decode_attr(node.attrs.get("encoding-type", ""))

    # Newer anndata may store obsm["S"] / obsm["spatial"] as a dataframe group:
    #   attrs: encoding-type="dataframe", column-order=["x", "y"]
    #   children: _index, x, y
    # Old anndata cannot read this, so we manually stack the numeric coordinate columns.
    if encoding_type == "dataframe":
        cols = _decode_attr(node.attrs.get("column-order", []))
        if cols is None:
            cols = []
        if isinstance(cols, str):
            cols = [cols]
        if not cols:
            cols = [k for k in node.keys() if k not in {"_index", "index"}]

        arrays = []
        used_cols = []
        for col in cols:
            if col in {"_index", "index"} or col not in node:
                continue
            try:
                values = np.asarray(_read_h5_vector(node[col]))
                if values.ndim == 1 and np.issubdtype(values.dtype, np.number):
                    arrays.append(values.astype(float))
                    used_cols.append(col)
            except Exception:
                pass

        if len(arrays) >= 2:
            mat = np.column_stack(arrays)
            logging.info(
                f"    [READ] parsed dataframe matrix with columns={used_cols}; shape={mat.shape}"
            )
            return mat

    if {"data", "indices", "indptr"}.issubset(keys):
        data = np.asarray(_read_h5_dataset(node["data"]))
        indices = np.asarray(_read_h5_dataset(node["indices"])).astype(np.int64)
        indptr = np.asarray(_read_h5_dataset(node["indptr"])).astype(np.int64)

        shape = _decode_attr(node.attrs.get("shape", None))
        if shape is None and "shape" in keys:
            shape = _read_h5_dataset(node["shape"])
        shape = tuple(np.asarray(shape).astype(int).tolist())

        if encoding_type == "csc_matrix":
            return sp.csc_matrix((data, indices, indptr), shape=shape).tocsr()
        return sp.csr_matrix((data, indices, indptr), shape=shape)

    # Dense array wrapped in a group.
    for key in ["values", "value", "data", "array", "X"]:
        if key in keys:
            try:
                return _read_h5_matrix(node[key])
            except Exception:
                pass

    if len(keys) == 1:
        only_key = next(iter(keys))
        return _read_h5_matrix(node[only_key])

    raise ValueError(f"Cannot read matrix from HDF5 group: {_h5_node_summary(node)}")


def _is_spatial_matrix(arr, n_obs: int) -> bool:
    """Return True if arr looks like spot coordinates."""
    if sp.issparse(arr):
        return False
    arr = np.asarray(arr)
    if arr.ndim != 2:
        return False
    if arr.shape[0] != n_obs:
        return False
    if arr.shape[1] < 2 or arr.shape[1] > 5:
        return False
    if not np.issubdtype(arr.dtype, np.number):
        return False
    return np.isfinite(arr[:, :2]).any()


def _choose_best_spatial_candidate(candidates):
    """Choose the most likely coordinate matrix from (name, path, arr) candidates."""
    if not candidates:
        return None

    def score(item):
        name, path, _ = item
        s = 0
        text = f"{name} {path}".lower()
        if "spatial" in text:
            s += 100
        if "coord" in text or "coordinate" in text:
            s += 80
        if "/obsm/" in path.lower():
            s += 60
        if name in {"S", "spatial"}:
            s += 50
        if "pxl" in text or "array" in text or "image" in text:
            s += 20
        return s

    return sorted(candidates, key=score, reverse=True)[0]


def _find_spatial_coordinates_in_h5(f: h5py.File, n_obs: int):
    """
    Robustly find coordinates in a newer h5ad file.
    First checks /obsm children; if needed, recursively scans small n_obs x 2-5 arrays.
    """
    candidates = []

    # First pass: explicit /obsm keys. This is the expected place for QuickSRT coordinates.
    if "obsm" in f:
        obsm_keys = list(f["obsm"].keys())
        logging.info(f"    [READ] HDF5 /obsm keys={obsm_keys}")
        for key in obsm_keys:
            node = f["obsm"][key]
            try:
                arr = np.asarray(_read_h5_matrix(node))
                if _is_spatial_matrix(arr, n_obs):
                    candidates.append((key, f"/obsm/{key}", arr[:, :2].astype(float)))
                    logging.info(f"    [READ] candidate coordinates from /obsm/{key}: {arr.shape}")
                else:
                    logging.debug(f"    [READ] /obsm/{key} not coordinate-like: shape={getattr(arr, 'shape', None)}")
            except Exception as e:
                logging.warning(f"    [READ] failed to parse /obsm/{key}: {e}")
    else:
        logging.warning("    [READ] HDF5 file has no /obsm group")

    if candidates:
        return _choose_best_spatial_candidate(candidates)

    # Second pass: scan all small matrices that look like spot coordinates.
    # This handles files where the spatial matrix is not named S/spatial.
    def visit(name, node):
        if candidates:
            # Still allow visit to finish cheaply; no hard stop in h5py.visititems.
            pass
        try:
            if isinstance(node, h5py.Dataset):
                shape = getattr(node, "shape", None)
                if shape is not None and len(shape) == 2 and shape[0] == n_obs and 2 <= shape[1] <= 5:
                    arr = np.asarray(_read_h5_dataset(node))
                    if _is_spatial_matrix(arr, n_obs):
                        candidates.append((Path(name).name, f"/{name}", arr[:, :2].astype(float)))
                        logging.info(f"    [READ] candidate coordinates from /{name}: {arr.shape}")
            elif isinstance(node, h5py.Group):
                # Try group-level matrix only for promising names, to avoid heavy accidental reads.
                text = name.lower()
                if any(tok in text for tok in ["obsm", "spatial", "coord", "pxl", "array", "image", "position"]):
                    try:
                        arr = np.asarray(_read_h5_matrix(node))
                        if _is_spatial_matrix(arr, n_obs):
                            candidates.append((Path(name).name, f"/{name}", arr[:, :2].astype(float)))
                            logging.info(f"    [READ] candidate coordinates from /{name}: {arr.shape}")
                    except Exception:
                        pass
        except Exception:
            pass

    f.visititems(visit)

    if candidates:
        return _choose_best_spatial_candidate(candidates)
    return None


def _get_dataframe_index(df_group: h5py.Group, fallback_n: int, preferred_names=()):
    """Read the index of an anndata obs/var dataframe group."""
    index_key = _decode_attr(df_group.attrs.get("_index", None))
    candidates = []
    if index_key is not None:
        candidates.append(index_key)
    candidates.extend(preferred_names)
    candidates.extend(["_index", "index", "obs_names", "var_names"])

    for key in candidates:
        if key in df_group:
            try:
                values = np.asarray(_read_h5_vector(df_group[key])).astype(str)
                if len(values) == fallback_n:
                    return values
            except Exception:
                continue

    return np.asarray([str(i) for i in range(fallback_n)])


def _get_dataframe_columns(df_group: h5py.Group):
    """Return column names from an anndata dataframe group."""
    cols = _decode_attr(df_group.attrs.get("column-order", []))
    if cols is None:
        cols = []
    if isinstance(cols, str):
        cols = [cols]
    seen = set(cols)
    for key in df_group.keys():
        if key not in seen:
            cols.append(key)
            seen.add(key)
    return cols


def _read_minimal_dataframe(df_group: h5py.Group, index_values, needed_columns=None):
    """Read a minimal obs/var dataframe, skipping nonessential columns that old anndata cannot read."""
    index_values = np.asarray(index_values).astype(str)
    n = len(index_values)
    needed_columns = set(needed_columns or [])

    data = {}
    index_key = _decode_attr(df_group.attrs.get("_index", None))
    skip_keys = {index_key, "_index", "index", "obs_names", "var_names", None}

    for col in _get_dataframe_columns(df_group):
        if col in skip_keys or col not in df_group:
            continue
        try:
            values = np.asarray(_read_h5_vector(df_group[col]))
            if values.ndim == 0:
                values = np.repeat(values.item(), n)
            if len(values) != n:
                if col in needed_columns:
                    raise ValueError(f"length {len(values)} != expected {n}")
                continue
            data[col] = values
        except Exception as e:
            if col in needed_columns:
                raise RuntimeError(
                    f"Failed to read required dataframe column {col!r}: {e}. "
                    f"Node summary: {_h5_node_summary(df_group[col])}"
                )
            logging.debug(f"    [READ] skipped dataframe column {col!r}: {e}")

    return pd.DataFrame(data, index=pd.Index(index_values.astype(str), name=None))


def read_h5ad_minimal_for_staligner(h5ad_path: Path):
    """
    Manual fallback reader for QuickSRT h5ad files.
    Returns AnnData with only X, obs labels, var index, and spatial coordinates.
    """
    h5ad_path = Path(h5ad_path)
    with h5py.File(h5ad_path, "r") as f:
        logging.info(f"    [READ] HDF5 root keys={list(f.keys())}")
        X = _read_h5_matrix(f["X"])
        n_obs, n_vars = X.shape

        obs_index = _get_dataframe_index(f["obs"], n_obs, preferred_names=("barcode", "barcodes"))
        var_index = _get_dataframe_index(f["var"], n_vars, preferred_names=("gene_ids", "gene_symbols", "features"))

        obs_needed = [GT_LABEL_COL] if GT_LABEL_COL is not None else []
        obs_extra = [
            "z", "layer", "Layer", "annotation", "Annotation", "Ground Truth",
            "ground_truth", "x", "y", "X", "Y", "array_col", "array_row",
            "pxl_col_in_fullres", "pxl_row_in_fullres", "imagecol", "imagerow",
            "spatial_x", "spatial_y",
        ]
        obs_cols = [c for c in obs_needed + obs_extra if c is not None]
        obs = _read_minimal_dataframe(f["obs"], obs_index, needed_columns=obs_needed)

        for col in obs_cols:
            if col in obs.columns or col not in f["obs"]:
                continue
            try:
                values = np.asarray(_read_h5_vector(f["obs"][col]))
                if len(values) == n_obs:
                    obs[col] = values
            except Exception as e:
                if col == GT_LABEL_COL:
                    raise
                logging.debug(f"    [READ] could not add obs column {col!r}: {e}")

        var = pd.DataFrame(index=pd.Index(var_index.astype(str), name=None))
        adata = ad.AnnData(X=X, obs=obs, var=var)

        coord_candidate = _find_spatial_coordinates_in_h5(f, n_obs)
        if coord_candidate is not None:
            key, path, coords = coord_candidate
            adata.obsm["spatial"] = coords
            adata.obsm["S"] = coords
            logging.info(f"    [READ] using spatial coordinates from {path}; shape={coords.shape}")
        else:
            logging.warning("    [READ] no coordinate matrix found in h5ad; will try obs coordinate columns later")

        return adata


def read_h5ad_legacy_safe(h5ad_path: Path):
    """
    Read a QuickSRT h5ad file safely in the old STAligner environment.
    First try scanpy/anndata; on failure, use a minimal h5py reader.
    """
    h5ad_path = Path(h5ad_path)

    try:
        adata = sc.read_h5ad(h5ad_path)
        if "spatial" not in adata.obsm and "S" in adata.obsm:
            adata.obsm["spatial"] = np.asarray(adata.obsm["S"])
        return adata
    except Exception as e:
        logging.warning(f"    [READ] {h5ad_path.name}: sc.read_h5ad failed in old anndata")
        logging.warning(f"    [READ] {h5ad_path.name}: {e}")
        logging.warning(f"    [READ] {h5ad_path.name}: using minimal h5py reader")
        return read_h5ad_minimal_for_staligner(h5ad_path)

# %% [markdown]
# # Subject-level data loading

# %%
# =============================================================================
# Subject-level data loading
# =============================================================================
def load_one_crc_sample_for_staligner(sample_id: str):
    """
    Load one CRC_CMS .h5ad sample and build its STAligner spatial graph before concatenation.
    This follows the official STAligner CRC_CMS logic, but reads your QuickSRT SCE_*.h5ad files.
    """
    h5ad_path = DATA_ROOT / f"SCE_{sample_id}.h5ad"
    logging.info(f"    [LOAD] Reading {h5ad_path}")
    if not h5ad_path.exists():
        raise FileNotFoundError(f"Missing .h5ad file: {h5ad_path}")

    adata_tmp = read_h5ad_legacy_safe(h5ad_path)
    adata_tmp.var_names_make_unique(join="++")

    logging.info(
        f"    [DIAG] {sample_id}: n_obs={adata_tmp.n_obs}, n_vars={adata_tmp.n_vars}"
    )
    logging.info(f"    [DIAG] {sample_id}: obs columns={list(adata_tmp.obs.columns)}")
    logging.info(f"    [DIAG] {sample_id}: obsm keys={list(adata_tmp.obsm.keys())}")

    gt_col = detect_gt_column(adata_tmp)
    label_series = adata_tmp.obs[gt_col].astype(object).copy()
    label_series[pd.isnull(label_series)] = "unknown"

    adata_tmp.obs["Ground Truth"] = label_series.astype("category")
    adata_tmp.obs["layer_guess"] = adata_tmp.obs["Ground Truth"].astype(object)
    adata_tmp.obs["batch_name"] = sample_id
    adata_tmp.obs["sample_id"] = sample_id
    adata_tmp.obs["sample"] = sample_id
    adata_tmp.obs["original_spot_id"] = adata_tmp.obs_names.astype(str)

    n_labeled = int(clean_label_mask(adata_tmp.obs["Ground Truth"]).sum())
    logging.info(
        f"    [DIAG] {sample_id}: using GT column '{gt_col}' "
        f"(labeled spots: {n_labeled}/{adata_tmp.n_obs})"
    )

    ensure_spatial_obsm(adata_tmp, sample_id)

    # Official tutorial makes spot names unique by appending section_id.
    adata_tmp.obs_names = [
        f"{spot_id}_{sample_id}" for spot_id in adata_tmp.obs["original_spot_id"].astype(str)
    ]

    logging.info(f"    [GRAPH] {sample_id}: Cal_Spatial_Net(rad_cutoff={RAD_CUTOFF})")
    STAligner.Cal_Spatial_Net(adata_tmp, rad_cutoff=int(RAD_CUTOFF))
    if "adj" not in adata_tmp.uns:
        raise KeyError(f"{sample_id}: STAligner.Cal_Spatial_Net did not create adata.uns['adj']")

    # Official tutorial-style expression preprocessing.
    n_hvg = min(int(N_TOP_GENES), int(adata_tmp.n_vars))
    logging.info(f"    [HVG] {sample_id}: selecting top {n_hvg} genes")
    try:
        sc.pp.highly_variable_genes(adata_tmp, flavor="seurat_v3", n_top_genes=n_hvg)
    except Exception as e:
        logging.warning(
            f"    [HVG] {sample_id}: seurat_v3 failed ({e}); falling back to flavor='seurat'"
        )
        sc.pp.highly_variable_genes(adata_tmp, flavor="seurat", n_top_genes=n_hvg)

    sc.pp.normalize_total(adata_tmp, target_sum=1e4)
    sc.pp.log1p(adata_tmp)
    adata_tmp = adata_tmp[:, adata_tmp.var["highly_variable"]].copy()

    logging.info(
        f"    [DONE] {sample_id}: after HVG/preprocess n_obs={adata_tmp.n_obs}, n_vars={adata_tmp.n_vars}"
    )
    return adata_tmp, gt_col


def load_crc_subject_group(subject_name: str, sample_ids: list):
    """
    Load and concatenate the CRC_CMS replicate samples for one subject, matching STAligner's
    multi-sample integration design.

    Returns:
        adata_concat : concatenated AnnData with adata_concat.uns['edgeList']
        gt_cols      : sample_id -> ground-truth column name
    """
    logging.info(f"  [GROUP] Loading {subject_name}: {sample_ids}")

    batch_list = []
    adj_list = []
    gt_cols = {}

    for sample_id in sample_ids:
        adata_sample, gt_col = load_one_crc_sample_for_staligner(sample_id)
        batch_list.append(adata_sample)
        adj_list.append(adata_sample.uns["adj"])
        gt_cols[sample_id] = gt_col

    logging.info(f"  [CONCAT] {subject_name}: concatenating AnnData objects")
    adata_concat = ad.concat(
        batch_list,
        label="sample_name",
        keys=sample_ids,
        join="inner",
        index_unique=None,
    )
    adata_concat.obs["Ground Truth"] = adata_concat.obs["Ground Truth"].astype("category")
    adata_concat.obs["batch_name"] = adata_concat.obs["batch_name"].astype(str)
    adata_concat.obs["sample_name"] = adata_concat.obs["sample_name"].astype(str)

    logging.info(
        f"  [CONCAT] {subject_name}: adata_concat shape={adata_concat.shape}; "
        f"sample counts={adata_concat.obs['batch_name'].value_counts().to_dict()}"
    )

    logging.info(f"  [GRAPH] {subject_name}: building block-diagonal spatial graph")
    adj_concat = sp.block_diag(adj_list, format="csr")
    adata_concat.uns["edgeList"] = adj_concat.nonzero()
    adata_concat.uns["adj"] = adj_concat

    logging.info(
        f"  [GRAPH] {subject_name}: adj shape={adj_concat.shape}, edges={adj_concat.nnz}"
    )
    return adata_concat, gt_cols

# %% [markdown]
# # Metrics and subject-level training

# %%
# =============================================================================
# Metrics and subject-level training
# =============================================================================
def compute_staligner_metrics(sub_adata, gt_key: str, pred_key: str):
    """
    Compute the same output fields used by the earlier benchmark notebooks:
    ARI, NMI, ACC, DIS.

    ACC follows the SpaCross-style aggregation:
        mean(NMI, HOM, COM)
    DIS is left as NaN because STAligner does not expose CHAOS/PAS utilities directly.
    """
    y_true = sub_adata.obs[gt_key].astype(str).to_numpy()
    y_pred = sub_adata.obs[pred_key].astype(str).to_numpy()

    ARI = float(sk_metrics.adjusted_rand_score(y_true, y_pred))
    NMI = float(sk_metrics.normalized_mutual_info_score(y_true, y_pred))
    HOM = float(sk_metrics.homogeneity_score(y_true, y_pred))
    COM = float(sk_metrics.completeness_score(y_true, y_pred))
    ACC = float(np.mean([NMI, HOM, COM]))

    CHAOS = np.nan
    PAS = np.nan
    DIS = np.nan

    return ARI, NMI, ACC, DIS, HOM, COM, CHAOS, PAS


def train_one_subject_group(
    subject_name: str,
    sample_ids: list,
    adata_concat,
    device,
    run_seed: int,
):
    """
    Run STAligner for one subject group and return sample-level metrics/predictions.
    """
    num_clusters = get_num_clusters()

    logging.info(
        f"  [TRAIN] Starting STAligner | subject={subject_name} | "
        f"samples={sample_ids} | k_clusters={num_clusters} | "
        f"knn_neigh={KNN_NEIGH} | device={device} | run_seed={run_seed}"
    )

    t0 = time.time()

    np.random.seed(666 + run_seed)
    torch.manual_seed(666 + run_seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(666 + run_seed)

    # Official STAligner tutorial core line:
    # adata_concat = STAligner.train_STAligner(adata_concat, verbose=True, knn_neigh=50, device=used_device)
    adata_concat = STAligner.train_STAligner(
        adata_concat,
        verbose=True,
        knn_neigh=int(KNN_NEIGH),
        device=device,
    )

    if "STAligner" not in adata_concat.obsm:
        raise KeyError("STAligner training finished but adata_concat.obsm['STAligner'] was not found")

    logging.info(
        f"  [DIAG] {subject_name}: STAligner embedding shape={adata_concat.obsm['STAligner'].shape}"
    )

    # Official tutorial clustering:
    # STAligner.mclust_R(adata_concat, num_cluster=7, used_obsm='STAligner')
    STAligner.mclust_R(
        adata_concat,
        num_cluster=int(num_clusters),
        used_obsm="STAligner",
    )

    if CLUST_METHOD not in adata_concat.obs.columns:
        raise KeyError(f"Expected clustering column {CLUST_METHOD!r} after mclust_R")

    pred_labels = adata_concat.obs[CLUST_METHOD].astype(str).to_numpy()
    logging.info(
        f"  [DIAG] {subject_name}: cluster sizes="
        f"{pd.Series(pred_labels).value_counts().sort_index().to_dict()}"
    )

    elapsed = time.time() - t0
    gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU"

    metrics_list = []
    pred_frames = []

    # Sample-level metrics and predictions.
    for sample_id in sample_ids:
        mask = adata_concat.obs["batch_name"].astype(str).to_numpy() == str(sample_id)
        sample_adata = adata_concat[mask].copy()

        labeled_mask = clean_label_mask(sample_adata.obs["Ground Truth"])
        labeled_sample = sample_adata[labeled_mask].copy()

        ARI, NMI, ACC, DIS, HOM, COM, CHAOS, PAS = compute_staligner_metrics(
            labeled_sample, gt_key="Ground Truth", pred_key=CLUST_METHOD
        )

        metrics = {
            "method": METHOD_NAME,
            "sample": sample_id,
            "run_seed": run_seed,
            "ARI": float(ARI),
            "NMI": float(NMI),
            "ACC": float(ACC),
            "DIS": float(DIS) if not pd.isna(DIS) else np.nan,
            # Allocate group runtime across its samples so sum(running_time_sec)
            # approximates the actual subject-level training time.
            "running_time_sec": round(elapsed / max(1, len(sample_ids)), 2),
            "gpu_model": gpu_name,
            "training_unit": subject_name,
            "training_samples": ",".join(sample_ids),
            "subject_running_time_sec": round(elapsed, 2),
            "num_clusters": int(num_clusters),
            "num_spots": int(sample_adata.n_obs),
            "num_labeled_spots": int(labeled_sample.n_obs),
            "num_training_spots": int(adata_concat.n_obs),
            "num_genes_after_concat": int(adata_concat.n_vars),
            "clust_method": CLUST_METHOD,
            "device": str(device),
            "HOM": float(HOM),
            "COM": float(COM),
            "CHAOS": float(CHAOS) if not pd.isna(CHAOS) else np.nan,
            "PAS": float(PAS) if not pd.isna(PAS) else np.nan,
            "rad_cutoff": int(RAD_CUTOFF),
            "n_top_genes": int(N_TOP_GENES),
            "knn_neigh": int(KNN_NEIGH),
        }
        metrics_list.append(metrics)

        logging.info(
            f"  [METRICS] {subject_name}/{sample_id}: "
            f"ARI={ARI:.4f}  NMI={NMI:.4f}  ACC={ACC:.4f}  "
            f"allocated_time={elapsed / len(sample_ids):.1f}s  "
            f"subject_time={elapsed:.1f}s  gpu={gpu_name}"
        )

        spot_ids = (
            sample_adata.obs["original_spot_id"].astype(str).to_numpy()
            if "original_spot_id" in sample_adata.obs.columns
            else sample_adata.obs_names.astype(str).to_numpy()
        )

        pred_frames.append(
            pd.DataFrame(
                {
                    "method": METHOD_NAME,
                    "sample": sample_id,
                    "run_seed": run_seed,
                    "spot_id": spot_ids,
                    "true_label": sample_adata.obs["Ground Truth"].astype(object).to_numpy(),
                    "pred_label": np.asarray(sample_adata.obs[CLUST_METHOD]).astype(str),
                }
            )
        )

    pred_df = pd.concat(pred_frames, ignore_index=True)

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return metrics_list, pred_df

# %% [markdown]
# # Main benchmark loop

# %%
# =============================================================================
# Main benchmark loop
# =============================================================================
def run_benchmark():
    setup_logging(OUTPUT_DIR)

    logging.info("=" * 72)
    logging.info("STAligner CRC_CMS Subject-Level Benchmarking Framework")
    logging.info("=" * 72)

    if not STALIGNER_ROOT.exists():
        raise FileNotFoundError(
            f"STALIGNER_ROOT not found: {STALIGNER_ROOT.resolve()}\n"
            f"Clone it with: git clone https://github.com/zhoux85/STAligner.git"
        )

    if str(STALIGNER_ROOT.resolve()) not in sys.path:
        sys.path.insert(0, str(STALIGNER_ROOT.resolve()))

    check_mclust_if_needed()
    check_parquet_support()
    device = get_device()

    if not DATA_ROOT.exists():
        raise FileNotFoundError(f"DATA_ROOT not found: {DATA_ROOT.resolve()}")

    logging.info(f"[PATHS] STALIGNER_ROOT = {STALIGNER_ROOT}")
    logging.info(f"[PATHS] DATA_ROOT      = {DATA_ROOT}")
    logging.info(f"[PATHS] OUTPUT_DIR     = {OUTPUT_DIR}")

    subject_groups = resolve_subject_groups(SUBJECT_GROUPS_TO_RUN)
    logging.info(f"[SUBJECTS] Will process {len(subject_groups)} subject group(s): {subject_groups}")
    logging.info(
        f"[SETTINGS] num_runs={NUM_RUNS}  num_clusters={FIXED_NUM_CLUSTERS}  "
        f"rad_cutoff={RAD_CUTOFF}  n_top_genes={N_TOP_GENES}  knn_neigh={KNN_NEIGH}"
    )
    logging.info("[MODE] subject-level multi-sample training; sample-level metrics/output")

    all_metrics = []
    all_predictions = []
    failed = []

    for i, (subject_name, sample_ids) in enumerate(subject_groups.items(), start=1):
        logging.info("")
        logging.info("-" * 72)
        logging.info(f"[{i}/{len(subject_groups)}] Subject group {subject_name}: {sample_ids}")
        logging.info("-" * 72)

        try:
            adata, gt_cols = load_crc_subject_group(
                subject_name=subject_name,
                sample_ids=sample_ids,
            )

            for run in range(NUM_RUNS):
                logging.info(f"  -> Run {run + 1}/{NUM_RUNS}")
                adata_run = adata.copy()

                metrics_list, pred_df = train_one_subject_group(
                    subject_name=subject_name,
                    sample_ids=sample_ids,
                    adata_concat=adata_run,
                    device=device,
                    run_seed=run,
                )

                for row in metrics_list:
                    row["gt_col"] = gt_cols.get(row["sample"], GT_LABEL_COL)
                all_metrics.extend(metrics_list)
                all_predictions.append(pred_df)

            if torch.cuda.is_available():
                torch.cuda.empty_cache()

        except Exception as e:
            logging.exception(f"[FAILED] Subject group {subject_name}: {e}")
            failed.append({"training_unit": subject_name, "error": str(e)})
            continue

    if not all_metrics:
        logging.error("No successful runs — nothing to save.")
        return

    predictions = pd.concat(all_predictions, ignore_index=True)
    performance = pd.DataFrame(all_metrics)

    perf_lead = [
        "method", "sample", "run_seed",
        "ARI", "NMI", "ACC", "DIS",
        "running_time_sec", "gpu_model",
        "training_unit", "training_samples", "subject_running_time_sec",
    ]
    performance = performance[
        perf_lead + [c for c in performance.columns if c not in perf_lead]
    ]

    # Keep prediction file exactly SpaCross/STG3Net-compatible.
    pred_lead = ["method", "sample", "run_seed", "spot_id", "true_label", "pred_label"]
    predictions = predictions[pred_lead]

    pred_path = OUTPUT_DIR / "predictions.parquet"
    perf_path = OUTPUT_DIR / "performance.parquet"
    predictions.to_parquet(pred_path, index=False)
    performance.to_parquet(perf_path, index=False)

    logging.info("")
    logging.info("=" * 72)
    logging.info("SAVED")
    logging.info("=" * 72)
    logging.info(f"  predictions.parquet -> {pred_path}  ({len(predictions):,} rows)")
    logging.info(f"  performance.parquet -> {perf_path}  ({len(performance):,} rows)")

    logging.info("")
    logging.info("Per-sample metrics:")
    show_cols = [
        "training_unit", "sample", "ARI", "NMI", "ACC", "DIS",
        "running_time_sec", "subject_running_time_sec",
    ]
    logging.info("\n" + performance[show_cols].to_string(index=False))

    logging.info("")
    logging.info(
        f"Overall mean ARI: {performance['ARI'].mean():.4f}  "
        f"NMI: {performance['NMI'].mean():.4f}  "
        f"ACC: {performance['ACC'].mean():.4f}  "
        f"DIS: {performance['DIS'].mean():.4f}"
    )
    logging.info(f"GPU model(s) used: {sorted(performance['gpu_model'].unique().tolist())}")
    logging.info(
        f"Total subject-level running time: "
        f"{performance[['training_unit', 'run_seed', 'subject_running_time_sec']].drop_duplicates()['subject_running_time_sec'].sum():.1f}s"
    )

    if failed:
        logging.warning(f"\n{len(failed)} subject group(s) failed:")
        for f_ in failed:
            logging.warning(f"  - {f_['training_unit']}: {f_['error']}")

    logging.info("\nBenchmarking complete.")


# Execute the benchmark when this cell is run.
run_benchmark()
# Out:
# 2026-05-18 00:00:30,325 [INFO] Log file: /home/dal875013/work/projects/mocha/results/STAligner/crc_cms_STAligner/benchmark.log
# 2026-05-18 00:00:30,326 [INFO] ========================================================================
# 2026-05-18 00:00:30,326 [INFO] STAligner CRC_CMS Subject-Level Benchmarking Framework
# 2026-05-18 00:00:30,327 [INFO] ========================================================================
# 2026-05-18 00:00:30,365 [WARNING] R[write to console]:                    __           __
#    ____ ___  _____/ /_  _______/ /_
#   / __ `__ \/ ___/ / / / / ___/ __/
#  / / / / / / /__/ / /_/ (__  ) /_
# /_/ /_/ /_/\___/_/\__,_/____/\__/   version 6.1
# Type 'citation("mclust")' for citing this R package in publications.
#
# 2026-05-18 00:00:30,367 [INFO] [CHECK] R package mclust is available
# 2026-05-18 00:00:30,473 [INFO] [CHECK] pyarrow is available: 10.0.1
# 2026-05-18 00:00:30,474 [INFO] [DEVICE] CUDA available — using cuda:0
# 2026-05-18 00:00:30,474 [INFO] [DEVICE] GPU name: NVIDIA A30
# 2026-05-18 00:00:30,475 [INFO] [DEVICE] GPU memory: 25.22 GB
# 2026-05-18 00:00:30,478 [INFO] [PATHS] STALIGNER_ROOT = /work/dal875013/projects/mocha/methods/STAligner
# 2026-05-18 00:00:30,478 [INFO] [PATHS] DATA_ROOT      = /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data
# 2026-05-18 00:00:30,479 [INFO] [PATHS] OUTPUT_DIR     = /home/dal875013/work/projects/mocha/results/STAligner/crc_cms_STAligner
# 2026-05-18 00:00:30,480 [INFO] [SUBJECTS] Will process 7 subject group(s): {'subject_1': ['SN048_A121573_Rep1', 'SN048_A121573_Rep2'], 'subject_2': ['SN048_A416371_Rep1', 'SN048_A416371_Rep2'], 'subject_3': ['SN123_A551763_Rep1', 'SN124_A551763_Rep2'], 'subject_4': ['SN123_A595688_Rep1', 'SN124_A595688_Rep2'], 'subject_5': ['SN123_A798015_Rep1', 'SN124_A798015_Rep2'], 'subject_6': ['SN123_A938797_Rep1_X', 'SN124_A938797_Rep2'], 'subject_7': ['SN84_A120838_Rep1', 'SN84_A120838_Rep2']}
# 2026-05-18 00:00:30,480 [INFO] [SETTINGS] num_runs=1  num_clusters=6  rad_cutoff=150  n_top_genes=5000  knn_neigh=50
# 2026-05-18 00:00:30,481 [INFO] [MODE] subject-level multi-sample training; sample-level metrics/output
# 2026-05-18 00:00:30,482 [INFO]
# 2026-05-18 00:00:30,482 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:00:30,483 [INFO] [1/7] Subject group subject_1: ['SN048_A121573_Rep1', 'SN048_A121573_Rep2']
# 2026-05-18 00:00:30,485 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:00:30,486 [INFO]   [GROUP] Loading subject_1: ['SN048_A121573_Rep1', 'SN048_A121573_Rep2']
# 2026-05-18 00:00:30,486 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN048_A121573_Rep1.h5ad
# 2026-05-18 00:00:31,279 [WARNING]     [READ] SCE_SN048_A121573_Rep1.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:00:31,280 [WARNING]     [READ] SCE_SN048_A121573_Rep1.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:00:31,281 [WARNING]     [READ] SCE_SN048_A121573_Rep1.h5ad: using minimal h5py reader
# 2026-05-18 00:00:31,283 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:00:31,407 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:00:31,410 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(2052, 2)
# 2026-05-18 00:00:31,411 [INFO]     [READ] candidate coordinates from /obsm/S: (2052, 2)
# 2026-05-18 00:00:31,412 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(2052, 2)
# 2026-05-18 00:00:31,417 [INFO]     [DIAG] SN048_A121573_Rep1: n_obs=2052, n_vars=36601
# 2026-05-18 00:00:31,418 [INFO]     [DIAG] SN048_A121573_Rep1: obs columns=['z']
# 2026-05-18 00:00:31,419 [INFO]     [DIAG] SN048_A121573_Rep1: obsm keys=['spatial', 'S']
# 2026-05-18 00:00:31,426 [INFO]     [DIAG] SN048_A121573_Rep1: using GT column 'z' (labeled spots: 2052/2052)
# 2026-05-18 00:00:31,428 [INFO]     [GRAPH] SN048_A121573_Rep1: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 102192 edges, 2052 cells.
# 49.8012 neighbors per cell on average.
# 2026-05-18 00:00:32,067 [INFO]     [HVG] SN048_A121573_Rep1: selecting top 5000 genes
# 2026-05-18 00:00:32,930 [INFO]     [DONE] SN048_A121573_Rep1: after HVG/preprocess n_obs=2052, n_vars=5000
# 2026-05-18 00:00:32,931 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN048_A121573_Rep2.h5ad
# 2026-05-18 00:00:33,345 [WARNING]     [READ] SCE_SN048_A121573_Rep2.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:00:33,346 [WARNING]     [READ] SCE_SN048_A121573_Rep2.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:00:33,347 [WARNING]     [READ] SCE_SN048_A121573_Rep2.h5ad: using minimal h5py reader
# 2026-05-18 00:00:33,349 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:00:33,457 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:00:33,459 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(2291, 2)
# 2026-05-18 00:00:33,460 [INFO]     [READ] candidate coordinates from /obsm/S: (2291, 2)
# 2026-05-18 00:00:33,461 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(2291, 2)
# 2026-05-18 00:00:33,465 [INFO]     [DIAG] SN048_A121573_Rep2: n_obs=2291, n_vars=36601
# 2026-05-18 00:00:33,466 [INFO]     [DIAG] SN048_A121573_Rep2: obs columns=['z']
# 2026-05-18 00:00:33,467 [INFO]     [DIAG] SN048_A121573_Rep2: obsm keys=['spatial', 'S']
# 2026-05-18 00:00:33,472 [INFO]     [DIAG] SN048_A121573_Rep2: using GT column 'z' (labeled spots: 2291/2291)
# 2026-05-18 00:00:33,473 [INFO]     [GRAPH] SN048_A121573_Rep2: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 113883 edges, 2291 cells.
# 49.7089 neighbors per cell on average.
# 2026-05-18 00:00:34,079 [INFO]     [HVG] SN048_A121573_Rep2: selecting top 5000 genes
# 2026-05-18 00:00:34,660 [INFO]     [DONE] SN048_A121573_Rep2: after HVG/preprocess n_obs=2291, n_vars=5000
# 2026-05-18 00:00:34,661 [INFO]   [CONCAT] subject_1: concatenating AnnData objects
# 2026-05-18 00:00:34,728 [INFO]   [CONCAT] subject_1: adata_concat shape=(4343, 2749); sample counts={'SN048_A121573_Rep2': 2291, 'SN048_A121573_Rep1': 2052}
# 2026-05-18 00:00:34,730 [INFO]   [GRAPH] subject_1: building block-diagonal spatial graph
# 2026-05-18 00:00:34,736 [INFO]   [GRAPH] subject_1: adj shape=(4343, 4343), edges=220418
# 2026-05-18 00:00:34,737 [INFO]   -> Run 1/1
# 2026-05-18 00:00:34,743 [INFO]   [TRAIN] Starting STAligner | subject=subject_1 | samples=['SN048_A121573_Rep1', 'SN048_A121573_Rep2'] | k_clusters=6 | knn_neigh=50 | device=cuda:0 | run_seed=0
# STAligner(
#   (conv1): GATConv(2749, 512, heads=1)
#   (conv2): GATConv(512, 30, heads=1)
#   (conv3): GATConv(30, 512, heads=1)
#   (conv4): GATConv(512, 2749, heads=1)
# )
# Pretrain with STAGATE...
# 100%|██████████| 500/500 [00:14<00:00, 34.40it/s]
# Train with STAligner...
#   0%|          | 0/500 [00:00<?, ?it/s]
# Update spot triplets at epoch 500
#  19%|█▉        | 97/500 [00:03<00:11, 35.56it/s]
# Update spot triplets at epoch 600
#  40%|████      | 200/500 [00:06<00:08, 35.51it/s]
# Update spot triplets at epoch 700
#  60%|██████    | 300/500 [00:10<00:05, 35.18it/s]
# Update spot triplets at epoch 800
#  80%|████████  | 400/500 [00:13<00:02, 35.16it/s]
# Update spot triplets at epoch 900
# 100%|██████████| 500/500 [00:17<00:00, 28.52it/s]
# 2026-05-18 00:01:12,814 [INFO]   [DIAG] subject_1: STAligner embedding shape=(4343, 30)
# fitting ...
#   |                                                                      |   0%
#   |======================================================================| 100%
# 2026-05-18 00:01:18,863 [INFO]   [DIAG] subject_1: cluster sizes={'1': 471, '2': 731, '3': 335, '4': 694, '5': 1475, '6': 637}
# 2026-05-18 00:01:18,896 [INFO]   [METRICS] subject_1/SN048_A121573_Rep1: ARI=0.2034  NMI=0.3118  ACC=0.3120  allocated_time=22.1s  subject_time=44.1s  gpu=NVIDIA A30
# 2026-05-18 00:01:18,933 [INFO]   [METRICS] subject_1/SN048_A121573_Rep2: ARI=0.1874  NMI=0.2986  ACC=0.2986  allocated_time=22.1s  subject_time=44.1s  gpu=NVIDIA A30
# 2026-05-18 00:01:18,938 [INFO]
# 2026-05-18 00:01:18,939 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:01:18,940 [INFO] [2/7] Subject group subject_2: ['SN048_A416371_Rep1', 'SN048_A416371_Rep2']
# 2026-05-18 00:01:18,940 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:01:18,941 [INFO]   [GROUP] Loading subject_2: ['SN048_A416371_Rep1', 'SN048_A416371_Rep2']
# 2026-05-18 00:01:18,942 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN048_A416371_Rep1.h5ad
# 2026-05-18 00:01:19,912 [WARNING]     [READ] SCE_SN048_A416371_Rep1.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:01:19,913 [WARNING]     [READ] SCE_SN048_A416371_Rep1.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:01:19,914 [WARNING]     [READ] SCE_SN048_A416371_Rep1.h5ad: using minimal h5py reader
# 2026-05-18 00:01:19,916 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:01:20,118 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:01:20,120 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(2317, 2)
# 2026-05-18 00:01:20,121 [INFO]     [READ] candidate coordinates from /obsm/S: (2317, 2)
# 2026-05-18 00:01:20,122 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(2317, 2)
# 2026-05-18 00:01:20,127 [INFO]     [DIAG] SN048_A416371_Rep1: n_obs=2317, n_vars=36601
# 2026-05-18 00:01:20,128 [INFO]     [DIAG] SN048_A416371_Rep1: obs columns=['z']
# 2026-05-18 00:01:20,129 [INFO]     [DIAG] SN048_A416371_Rep1: obsm keys=['spatial', 'S']
# 2026-05-18 00:01:20,133 [INFO]     [DIAG] SN048_A416371_Rep1: using GT column 'z' (labeled spots: 2317/2317)
# 2026-05-18 00:01:20,135 [INFO]     [GRAPH] SN048_A416371_Rep1: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 115475 edges, 2317 cells.
# 49.8382 neighbors per cell on average.
# 2026-05-18 00:01:21,020 [INFO]     [HVG] SN048_A416371_Rep1: selecting top 5000 genes
# 2026-05-18 00:01:21,475 [INFO]     [DONE] SN048_A416371_Rep1: after HVG/preprocess n_obs=2317, n_vars=5000
# 2026-05-18 00:01:21,476 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN048_A416371_Rep2.h5ad
# 2026-05-18 00:01:22,395 [WARNING]     [READ] SCE_SN048_A416371_Rep2.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:01:22,396 [WARNING]     [READ] SCE_SN048_A416371_Rep2.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:01:22,397 [WARNING]     [READ] SCE_SN048_A416371_Rep2.h5ad: using minimal h5py reader
# 2026-05-18 00:01:22,399 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:01:22,511 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:01:22,513 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(1803, 2)
# 2026-05-18 00:01:22,514 [INFO]     [READ] candidate coordinates from /obsm/S: (1803, 2)
# 2026-05-18 00:01:22,515 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(1803, 2)
# 2026-05-18 00:01:22,520 [INFO]     [DIAG] SN048_A416371_Rep2: n_obs=1803, n_vars=36601
# 2026-05-18 00:01:22,521 [INFO]     [DIAG] SN048_A416371_Rep2: obs columns=['z']
# 2026-05-18 00:01:22,521 [INFO]     [DIAG] SN048_A416371_Rep2: obsm keys=['spatial', 'S']
# 2026-05-18 00:01:22,526 [INFO]     [DIAG] SN048_A416371_Rep2: using GT column 'z' (labeled spots: 1802/1803)
# 2026-05-18 00:01:22,527 [INFO]     [GRAPH] SN048_A416371_Rep2: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 89909 edges, 1803 cells.
# 49.8663 neighbors per cell on average.
# 2026-05-18 00:01:23,091 [INFO]     [HVG] SN048_A416371_Rep2: selecting top 5000 genes
# 2026-05-18 00:01:23,491 [INFO]     [DONE] SN048_A416371_Rep2: after HVG/preprocess n_obs=1803, n_vars=5000
# 2026-05-18 00:01:23,492 [INFO]   [CONCAT] subject_2: concatenating AnnData objects
# 2026-05-18 00:01:23,558 [INFO]   [CONCAT] subject_2: adata_concat shape=(4120, 2568); sample counts={'SN048_A416371_Rep1': 2317, 'SN048_A416371_Rep2': 1803}
# 2026-05-18 00:01:23,559 [INFO]   [GRAPH] subject_2: building block-diagonal spatial graph
# 2026-05-18 00:01:23,564 [INFO]   [GRAPH] subject_2: adj shape=(4120, 4120), edges=209504
# 2026-05-18 00:01:23,564 [INFO]   -> Run 1/1
# 2026-05-18 00:01:23,569 [INFO]   [TRAIN] Starting STAligner | subject=subject_2 | samples=['SN048_A416371_Rep1', 'SN048_A416371_Rep2'] | k_clusters=6 | knn_neigh=50 | device=cuda:0 | run_seed=0
# STAligner(
#   (conv1): GATConv(2568, 512, heads=1)
#   (conv2): GATConv(512, 30, heads=1)
#   (conv3): GATConv(30, 512, heads=1)
#   (conv4): GATConv(512, 2568, heads=1)
# )
# Pretrain with STAGATE...
# 100%|██████████| 500/500 [00:13<00:00, 37.14it/s]
# Train with STAligner...
#   0%|          | 0/500 [00:00<?, ?it/s]
# Update spot triplets at epoch 500
#  19%|█▉        | 97/500 [00:03<00:10, 38.19it/s]
# Update spot triplets at epoch 600
#  39%|███▉      | 197/500 [00:06<00:08, 34.24it/s]
# Update spot triplets at epoch 700
#  59%|█████▉    | 297/500 [00:09<00:05, 38.22it/s]
# Update spot triplets at epoch 800
#  79%|███████▉  | 397/500 [00:12<00:02, 38.22it/s]
# Update spot triplets at epoch 900
# 100%|██████████| 500/500 [00:16<00:00, 31.00it/s]
# 2026-05-18 00:01:53,413 [INFO]   [DIAG] subject_2: STAligner embedding shape=(4120, 30)
# fitting ...
#   |======================================================================| 100%
# 2026-05-18 00:01:59,607 [INFO]   [DIAG] subject_2: cluster sizes={'1': 1102, '2': 479, '3': 741, '4': 863, '5': 672, '6': 263}
# 2026-05-18 00:01:59,639 [INFO]   [METRICS] subject_2/SN048_A416371_Rep1: ARI=0.0358  NMI=0.0750  ACC=0.0758  allocated_time=18.0s  subject_time=36.0s  gpu=NVIDIA A30
# 2026-05-18 00:01:59,665 [INFO]   [METRICS] subject_2/SN048_A416371_Rep2: ARI=0.0553  NMI=0.0949  ACC=0.0963  allocated_time=18.0s  subject_time=36.0s  gpu=NVIDIA A30
# 2026-05-18 00:01:59,671 [INFO]
# 2026-05-18 00:01:59,672 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:01:59,673 [INFO] [3/7] Subject group subject_3: ['SN123_A551763_Rep1', 'SN124_A551763_Rep2']
# 2026-05-18 00:01:59,673 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:01:59,674 [INFO]   [GROUP] Loading subject_3: ['SN123_A551763_Rep1', 'SN124_A551763_Rep2']
# 2026-05-18 00:01:59,675 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN123_A551763_Rep1.h5ad
# 2026-05-18 00:01:59,995 [WARNING]     [READ] SCE_SN123_A551763_Rep1.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:01:59,996 [WARNING]     [READ] SCE_SN123_A551763_Rep1.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:01:59,997 [WARNING]     [READ] SCE_SN123_A551763_Rep1.h5ad: using minimal h5py reader
# 2026-05-18 00:02:00,012 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:02:00,072 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:02:00,075 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(665, 2)
# 2026-05-18 00:02:00,075 [INFO]     [READ] candidate coordinates from /obsm/S: (665, 2)
# 2026-05-18 00:02:00,076 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(665, 2)
# 2026-05-18 00:02:00,080 [INFO]     [DIAG] SN123_A551763_Rep1: n_obs=665, n_vars=36601
# 2026-05-18 00:02:00,081 [INFO]     [DIAG] SN123_A551763_Rep1: obs columns=['z']
# 2026-05-18 00:02:00,082 [INFO]     [DIAG] SN123_A551763_Rep1: obsm keys=['spatial', 'S']
# 2026-05-18 00:02:00,086 [INFO]     [DIAG] SN123_A551763_Rep1: using GT column 'z' (labeled spots: 665/665)
# 2026-05-18 00:02:00,087 [INFO]     [GRAPH] SN123_A551763_Rep1: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 33047 edges, 665 cells.
# 49.6947 neighbors per cell on average.
# 2026-05-18 00:02:00,348 [INFO]     [HVG] SN123_A551763_Rep1: selecting top 5000 genes
# 2026-05-18 00:02:00,510 [INFO]     [DONE] SN123_A551763_Rep1: after HVG/preprocess n_obs=665, n_vars=5000
# 2026-05-18 00:02:00,512 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN124_A551763_Rep2.h5ad
# 2026-05-18 00:02:00,682 [WARNING]     [READ] SCE_SN124_A551763_Rep2.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:02:00,683 [WARNING]     [READ] SCE_SN124_A551763_Rep2.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:02:00,683 [WARNING]     [READ] SCE_SN124_A551763_Rep2.h5ad: using minimal h5py reader
# 2026-05-18 00:02:00,687 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:02:00,740 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:02:00,742 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(1165, 2)
# 2026-05-18 00:02:00,743 [INFO]     [READ] candidate coordinates from /obsm/S: (1165, 2)
# 2026-05-18 00:02:00,743 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(1165, 2)
# 2026-05-18 00:02:00,747 [INFO]     [DIAG] SN124_A551763_Rep2: n_obs=1165, n_vars=36601
# 2026-05-18 00:02:00,748 [INFO]     [DIAG] SN124_A551763_Rep2: obs columns=['z']
# 2026-05-18 00:02:00,748 [INFO]     [DIAG] SN124_A551763_Rep2: obsm keys=['spatial', 'S']
# 2026-05-18 00:02:00,752 [INFO]     [DIAG] SN124_A551763_Rep2: using GT column 'z' (labeled spots: 1162/1165)
# 2026-05-18 00:02:00,753 [INFO]     [GRAPH] SN124_A551763_Rep2: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 57865 edges, 1165 cells.
# 49.6695 neighbors per cell on average.
# 2026-05-18 00:02:01,078 [INFO]     [HVG] SN124_A551763_Rep2: selecting top 5000 genes
# 2026-05-18 00:02:01,168 [INFO]     [DONE] SN124_A551763_Rep2: after HVG/preprocess n_obs=1165, n_vars=5000
# 2026-05-18 00:02:01,169 [INFO]   [CONCAT] subject_3: concatenating AnnData objects
# 2026-05-18 00:02:01,192 [INFO]   [CONCAT] subject_3: adata_concat shape=(1830, 1836); sample counts={'SN124_A551763_Rep2': 1165, 'SN123_A551763_Rep1': 665}
# 2026-05-18 00:02:01,193 [INFO]   [GRAPH] subject_3: building block-diagonal spatial graph
# 2026-05-18 00:02:01,196 [INFO]   [GRAPH] subject_3: adj shape=(1830, 1830), edges=92742
# 2026-05-18 00:02:01,197 [INFO]   -> Run 1/1
# 2026-05-18 00:02:01,199 [INFO]   [TRAIN] Starting STAligner | subject=subject_3 | samples=['SN123_A551763_Rep1', 'SN124_A551763_Rep2'] | k_clusters=6 | knn_neigh=50 | device=cuda:0 | run_seed=0
# STAligner(
#   (conv1): GATConv(1836, 512, heads=1)
#   (conv2): GATConv(512, 30, heads=1)
#   (conv3): GATConv(30, 512, heads=1)
#   (conv4): GATConv(512, 1836, heads=1)
# )
# Pretrain with STAGATE...
# 100%|██████████| 500/500 [00:06<00:00, 78.29it/s]
# Train with STAligner...
#   0%|          | 1/500 [00:00<01:22,  6.06it/s]
# Update spot triplets at epoch 500
#  20%|██        | 100/500 [00:01<00:04, 82.36it/s]
# Update spot triplets at epoch 600
#  40%|███▉      | 199/500 [00:02<00:03, 81.97it/s]
# Update spot triplets at epoch 700
#  60%|█████▉    | 298/500 [00:04<00:02, 81.01it/s]
# Update spot triplets at epoch 800
#  79%|███████▉  | 394/500 [00:05<00:01, 80.17it/s]
# Update spot triplets at epoch 900
# 100%|██████████| 500/500 [00:07<00:00, 69.61it/s]
# 2026-05-18 00:02:15,032 [INFO]   [DIAG] subject_3: STAligner embedding shape=(1830, 30)
# fitting ...
#   |======================================================================| 100%
# 2026-05-18 00:02:19,103 [INFO]   [DIAG] subject_3: cluster sizes={'1': 557, '2': 377, '3': 178, '4': 236, '5': 188, '6': 294}
# 2026-05-18 00:02:19,116 [INFO]   [METRICS] subject_3/SN123_A551763_Rep1: ARI=0.0108  NMI=0.0745  ACC=0.0782  allocated_time=9.0s  subject_time=17.9s  gpu=NVIDIA A30
# 2026-05-18 00:02:19,132 [INFO]   [METRICS] subject_3/SN124_A551763_Rep2: ARI=0.0164  NMI=0.0343  ACC=0.0370  allocated_time=9.0s  subject_time=17.9s  gpu=NVIDIA A30
# 2026-05-18 00:02:19,136 [INFO]
# 2026-05-18 00:02:19,137 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:02:19,138 [INFO] [4/7] Subject group subject_4: ['SN123_A595688_Rep1', 'SN124_A595688_Rep2']
# 2026-05-18 00:02:19,138 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:02:19,139 [INFO]   [GROUP] Loading subject_4: ['SN123_A595688_Rep1', 'SN124_A595688_Rep2']
# 2026-05-18 00:02:19,139 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN123_A595688_Rep1.h5ad
# 2026-05-18 00:02:19,439 [WARNING]     [READ] SCE_SN123_A595688_Rep1.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:02:19,440 [WARNING]     [READ] SCE_SN123_A595688_Rep1.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:02:19,441 [WARNING]     [READ] SCE_SN123_A595688_Rep1.h5ad: using minimal h5py reader
# 2026-05-18 00:02:19,443 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:02:19,555 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:02:19,557 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(1111, 2)
# 2026-05-18 00:02:19,558 [INFO]     [READ] candidate coordinates from /obsm/S: (1111, 2)
# 2026-05-18 00:02:19,558 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(1111, 2)
# 2026-05-18 00:02:19,563 [INFO]     [DIAG] SN123_A595688_Rep1: n_obs=1111, n_vars=36601
# 2026-05-18 00:02:19,563 [INFO]     [DIAG] SN123_A595688_Rep1: obs columns=['z']
# 2026-05-18 00:02:19,564 [INFO]     [DIAG] SN123_A595688_Rep1: obsm keys=['spatial', 'S']
# 2026-05-18 00:02:19,569 [INFO]     [DIAG] SN123_A595688_Rep1: using GT column 'z' (labeled spots: 1111/1111)
# 2026-05-18 00:02:19,570 [INFO]     [GRAPH] SN123_A595688_Rep1: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 55199 edges, 1111 cells.
# 49.6841 neighbors per cell on average.
# 2026-05-18 00:02:19,951 [INFO]     [HVG] SN123_A595688_Rep1: selecting top 5000 genes
# 2026-05-18 00:02:20,197 [INFO]     [DONE] SN123_A595688_Rep1: after HVG/preprocess n_obs=1111, n_vars=5000
# 2026-05-18 00:02:20,198 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN124_A595688_Rep2.h5ad
# 2026-05-18 00:02:20,345 [WARNING]     [READ] SCE_SN124_A595688_Rep2.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:02:20,346 [WARNING]     [READ] SCE_SN124_A595688_Rep2.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:02:20,347 [WARNING]     [READ] SCE_SN124_A595688_Rep2.h5ad: using minimal h5py reader
# 2026-05-18 00:02:20,349 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:02:20,390 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:02:20,392 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(356, 2)
# 2026-05-18 00:02:20,393 [INFO]     [READ] candidate coordinates from /obsm/S: (356, 2)
# 2026-05-18 00:02:20,393 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(356, 2)
# 2026-05-18 00:02:20,397 [INFO]     [DIAG] SN124_A595688_Rep2: n_obs=356, n_vars=36601
# 2026-05-18 00:02:20,397 [INFO]     [DIAG] SN124_A595688_Rep2: obs columns=['z']
# 2026-05-18 00:02:20,398 [INFO]     [DIAG] SN124_A595688_Rep2: obsm keys=['spatial', 'S']
# 2026-05-18 00:02:20,402 [INFO]     [DIAG] SN124_A595688_Rep2: using GT column 'z' (labeled spots: 356/356)
# 2026-05-18 00:02:20,403 [INFO]     [GRAPH] SN124_A595688_Rep2: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 17497 edges, 356 cells.
# 49.1489 neighbors per cell on average.
# 2026-05-18 00:02:20,503 [INFO]     [HVG] SN124_A595688_Rep2: selecting top 5000 genes
# 2026-05-18 00:02:20,597 [INFO]     [DONE] SN124_A595688_Rep2: after HVG/preprocess n_obs=356, n_vars=5000
# 2026-05-18 00:02:20,598 [INFO]   [CONCAT] subject_4: concatenating AnnData objects
# 2026-05-18 00:02:20,625 [INFO]   [CONCAT] subject_4: adata_concat shape=(1467, 2329); sample counts={'SN123_A595688_Rep1': 1111, 'SN124_A595688_Rep2': 356}
# 2026-05-18 00:02:20,626 [INFO]   [GRAPH] subject_4: building block-diagonal spatial graph
# 2026-05-18 00:02:20,628 [INFO]   [GRAPH] subject_4: adj shape=(1467, 1467), edges=74163
# 2026-05-18 00:02:20,629 [INFO]   -> Run 1/1
# 2026-05-18 00:02:20,631 [INFO]   [TRAIN] Starting STAligner | subject=subject_4 | samples=['SN123_A595688_Rep1', 'SN124_A595688_Rep2'] | k_clusters=6 | knn_neigh=50 | device=cuda:0 | run_seed=0
# STAligner(
#   (conv1): GATConv(2329, 512, heads=1)
#   (conv2): GATConv(512, 30, heads=1)
#   (conv3): GATConv(30, 512, heads=1)
#   (conv4): GATConv(512, 2329, heads=1)
# )
# Pretrain with STAGATE...
# 100%|██████████| 500/500 [00:05<00:00, 90.77it/s]
# Train with STAligner...
#   0%|          | 1/500 [00:00<01:15,  6.60it/s]
# Update spot triplets at epoch 500
#  19%|█▉        | 97/500 [00:01<00:04, 89.27it/s]
# Update spot triplets at epoch 600
#  39%|███▉      | 197/500 [00:02<00:03, 93.55it/s]
# Update spot triplets at epoch 700
#  59%|█████▉    | 297/500 [00:03<00:02, 93.95it/s]
# Update spot triplets at epoch 800
#  79%|███████▉  | 397/500 [00:04<00:01, 93.95it/s]
# Update spot triplets at epoch 900
# 100%|██████████| 500/500 [00:06<00:00, 79.19it/s]
# 2026-05-18 00:02:32,682 [INFO]   [DIAG] subject_4: STAligner embedding shape=(1467, 30)
# fitting ...
#   |======================================================================| 100%
# 2026-05-18 00:02:34,868 [INFO]   [DIAG] subject_4: cluster sizes={'1': 392, '2': 206, '3': 229, '4': 326, '5': 160, '6': 154}
# 2026-05-18 00:02:34,888 [INFO]   [METRICS] subject_4/SN123_A595688_Rep1: ARI=0.2444  NMI=0.3944  ACC=0.3968  allocated_time=7.1s  subject_time=14.2s  gpu=NVIDIA A30
# 2026-05-18 00:02:34,900 [INFO]   [METRICS] subject_4/SN124_A595688_Rep2: ARI=0.2140  NMI=0.3912  ACC=0.3915  allocated_time=7.1s  subject_time=14.2s  gpu=NVIDIA A30
# 2026-05-18 00:02:34,904 [INFO]
# 2026-05-18 00:02:34,904 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:02:34,905 [INFO] [5/7] Subject group subject_5: ['SN123_A798015_Rep1', 'SN124_A798015_Rep2']
# 2026-05-18 00:02:34,905 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:02:34,906 [INFO]   [GROUP] Loading subject_5: ['SN123_A798015_Rep1', 'SN124_A798015_Rep2']
# 2026-05-18 00:02:34,907 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN123_A798015_Rep1.h5ad
# 2026-05-18 00:02:35,168 [WARNING]     [READ] SCE_SN123_A798015_Rep1.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:02:35,169 [WARNING]     [READ] SCE_SN123_A798015_Rep1.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:02:35,170 [WARNING]     [READ] SCE_SN123_A798015_Rep1.h5ad: using minimal h5py reader
# 2026-05-18 00:02:35,172 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:02:35,256 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:02:35,258 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(1635, 2)
# 2026-05-18 00:02:35,259 [INFO]     [READ] candidate coordinates from /obsm/S: (1635, 2)
# 2026-05-18 00:02:35,259 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(1635, 2)
# 2026-05-18 00:02:35,264 [INFO]     [DIAG] SN123_A798015_Rep1: n_obs=1635, n_vars=36601
# 2026-05-18 00:02:35,265 [INFO]     [DIAG] SN123_A798015_Rep1: obs columns=['z']
# 2026-05-18 00:02:35,265 [INFO]     [DIAG] SN123_A798015_Rep1: obsm keys=['spatial', 'S']
# 2026-05-18 00:02:35,270 [INFO]     [DIAG] SN123_A798015_Rep1: using GT column 'z' (labeled spots: 1609/1635)
# 2026-05-18 00:02:35,272 [INFO]     [GRAPH] SN123_A798015_Rep1: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 81714 edges, 1635 cells.
# 49.9780 neighbors per cell on average.
# 2026-05-18 00:02:35,729 [INFO]     [HVG] SN123_A798015_Rep1: selecting top 5000 genes
# 2026-05-18 00:02:35,952 [INFO]     [DONE] SN123_A798015_Rep1: after HVG/preprocess n_obs=1635, n_vars=5000
# 2026-05-18 00:02:35,953 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN124_A798015_Rep2.h5ad
# 2026-05-18 00:02:36,373 [WARNING]     [READ] SCE_SN124_A798015_Rep2.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:02:36,375 [WARNING]     [READ] SCE_SN124_A798015_Rep2.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:02:36,375 [WARNING]     [READ] SCE_SN124_A798015_Rep2.h5ad: using minimal h5py reader
# 2026-05-18 00:02:36,377 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:02:36,459 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:02:36,461 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(1574, 2)
# 2026-05-18 00:02:36,462 [INFO]     [READ] candidate coordinates from /obsm/S: (1574, 2)
# 2026-05-18 00:02:36,463 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(1574, 2)
# 2026-05-18 00:02:36,468 [INFO]     [DIAG] SN124_A798015_Rep2: n_obs=1574, n_vars=36601
# 2026-05-18 00:02:36,468 [INFO]     [DIAG] SN124_A798015_Rep2: obs columns=['z']
# 2026-05-18 00:02:36,469 [INFO]     [DIAG] SN124_A798015_Rep2: obsm keys=['spatial', 'S']
# 2026-05-18 00:02:36,474 [INFO]     [DIAG] SN124_A798015_Rep2: using GT column 'z' (labeled spots: 1478/1574)
# 2026-05-18 00:02:36,475 [INFO]     [GRAPH] SN124_A798015_Rep2: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 78606 edges, 1574 cells.
# 49.9403 neighbors per cell on average.
# 2026-05-18 00:02:37,224 [INFO]     [HVG] SN124_A798015_Rep2: selecting top 5000 genes
# 2026-05-18 00:02:37,457 [INFO]     [DONE] SN124_A798015_Rep2: after HVG/preprocess n_obs=1574, n_vars=5000
# 2026-05-18 00:02:37,459 [INFO]   [CONCAT] subject_5: concatenating AnnData objects
# 2026-05-18 00:02:37,491 [INFO]   [CONCAT] subject_5: adata_concat shape=(3209, 3120); sample counts={'SN123_A798015_Rep1': 1635, 'SN124_A798015_Rep2': 1574}
# 2026-05-18 00:02:37,492 [INFO]   [GRAPH] subject_5: building block-diagonal spatial graph
# 2026-05-18 00:02:37,496 [INFO]   [GRAPH] subject_5: adj shape=(3209, 3209), edges=163529
# 2026-05-18 00:02:37,497 [INFO]   -> Run 1/1
# 2026-05-18 00:02:37,499 [INFO]   [TRAIN] Starting STAligner | subject=subject_5 | samples=['SN123_A798015_Rep1', 'SN124_A798015_Rep2'] | k_clusters=6 | knn_neigh=50 | device=cuda:0 | run_seed=0
# STAligner(
#   (conv1): GATConv(3120, 512, heads=1)
#   (conv2): GATConv(512, 30, heads=1)
#   (conv3): GATConv(30, 512, heads=1)
#   (conv4): GATConv(512, 3120, heads=1)
# )
# Pretrain with STAGATE...
# 100%|██████████| 500/500 [00:10<00:00, 46.84it/s]
# Train with STAligner...
#   0%|          | 0/500 [00:00<?, ?it/s]
# Update spot triplets at epoch 500
#  19%|█▉        | 96/500 [00:02<00:08, 47.98it/s]
# Update spot triplets at epoch 600
#  39%|███▉      | 196/500 [00:05<00:06, 47.89it/s]
# Update spot triplets at epoch 700
#  59%|█████▉    | 296/500 [00:07<00:04, 47.93it/s]
# Update spot triplets at epoch 800
#  79%|███████▉  | 396/500 [00:10<00:02, 47.94it/s]
# Update spot triplets at epoch 900
# 100%|██████████| 500/500 [00:13<00:00, 38.11it/s]
# 2026-05-18 00:03:01,536 [INFO]   [DIAG] subject_5: STAligner embedding shape=(3209, 30)
# fitting ...
#   |                                                                      |   0%
#   |======================================================================| 100%
# 2026-05-18 00:03:10,540 [INFO]   [DIAG] subject_5: cluster sizes={'1': 565, '2': 807, '3': 503, '4': 568, '5': 410, '6': 356}
# 2026-05-18 00:03:10,564 [INFO]   [METRICS] subject_5/SN123_A798015_Rep1: ARI=0.1836  NMI=0.3500  ACC=0.3506  allocated_time=16.5s  subject_time=33.0s  gpu=NVIDIA A30
# 2026-05-18 00:03:10,588 [INFO]   [METRICS] subject_5/SN124_A798015_Rep2: ARI=0.2337  NMI=0.4005  ACC=0.4019  allocated_time=16.5s  subject_time=33.0s  gpu=NVIDIA A30
# 2026-05-18 00:03:10,593 [INFO]
# 2026-05-18 00:03:10,594 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:03:10,595 [INFO] [6/7] Subject group subject_6: ['SN123_A938797_Rep1_X', 'SN124_A938797_Rep2']
# 2026-05-18 00:03:10,596 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:03:10,596 [INFO]   [GROUP] Loading subject_6: ['SN123_A938797_Rep1_X', 'SN124_A938797_Rep2']
# 2026-05-18 00:03:10,597 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN123_A938797_Rep1_X.h5ad
# 2026-05-18 00:03:11,263 [WARNING]     [READ] SCE_SN123_A938797_Rep1_X.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:03:11,265 [WARNING]     [READ] SCE_SN123_A938797_Rep1_X.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:03:11,265 [WARNING]     [READ] SCE_SN123_A938797_Rep1_X.h5ad: using minimal h5py reader
# 2026-05-18 00:03:11,268 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:03:11,388 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:03:11,391 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(1945, 2)
# 2026-05-18 00:03:11,391 [INFO]     [READ] candidate coordinates from /obsm/S: (1945, 2)
# 2026-05-18 00:03:11,392 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(1945, 2)
# 2026-05-18 00:03:11,396 [INFO]     [DIAG] SN123_A938797_Rep1_X: n_obs=1945, n_vars=36601
# 2026-05-18 00:03:11,397 [INFO]     [DIAG] SN123_A938797_Rep1_X: obs columns=['z']
# 2026-05-18 00:03:11,397 [INFO]     [DIAG] SN123_A938797_Rep1_X: obsm keys=['spatial', 'S']
# 2026-05-18 00:03:11,402 [INFO]     [DIAG] SN123_A938797_Rep1_X: using GT column 'z' (labeled spots: 1944/1945)
# 2026-05-18 00:03:11,404 [INFO]     [GRAPH] SN123_A938797_Rep1_X: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 96840 edges, 1945 cells.
# 49.7892 neighbors per cell on average.
# 2026-05-18 00:03:11,935 [INFO]     [HVG] SN123_A938797_Rep1_X: selecting top 5000 genes
# 2026-05-18 00:03:12,240 [INFO]     [DONE] SN123_A938797_Rep1_X: after HVG/preprocess n_obs=1945, n_vars=5000
# 2026-05-18 00:03:12,242 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN124_A938797_Rep2.h5ad
# 2026-05-18 00:03:12,656 [WARNING]     [READ] SCE_SN124_A938797_Rep2.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:03:12,658 [WARNING]     [READ] SCE_SN124_A938797_Rep2.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:03:12,658 [WARNING]     [READ] SCE_SN124_A938797_Rep2.h5ad: using minimal h5py reader
# 2026-05-18 00:03:12,661 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:03:12,791 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:03:12,794 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(1485, 2)
# 2026-05-18 00:03:12,795 [INFO]     [READ] candidate coordinates from /obsm/S: (1485, 2)
# 2026-05-18 00:03:12,795 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(1485, 2)
# 2026-05-18 00:03:12,801 [INFO]     [DIAG] SN124_A938797_Rep2: n_obs=1485, n_vars=36601
# 2026-05-18 00:03:12,801 [INFO]     [DIAG] SN124_A938797_Rep2: obs columns=['z']
# 2026-05-18 00:03:12,802 [INFO]     [DIAG] SN124_A938797_Rep2: obsm keys=['spatial', 'S']
# 2026-05-18 00:03:12,807 [INFO]     [DIAG] SN124_A938797_Rep2: using GT column 'z' (labeled spots: 1485/1485)
# 2026-05-18 00:03:12,808 [INFO]     [GRAPH] SN124_A938797_Rep2: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 74094 edges, 1485 cells.
# 49.8949 neighbors per cell on average.
# 2026-05-18 00:03:13,316 [INFO]     [HVG] SN124_A938797_Rep2: selecting top 5000 genes
# 2026-05-18 00:03:13,696 [INFO]     [DONE] SN124_A938797_Rep2: after HVG/preprocess n_obs=1485, n_vars=5000
# 2026-05-18 00:03:13,698 [INFO]   [CONCAT] subject_6: concatenating AnnData objects
# 2026-05-18 00:03:13,748 [INFO]   [CONCAT] subject_6: adata_concat shape=(3430, 2858); sample counts={'SN123_A938797_Rep1_X': 1945, 'SN124_A938797_Rep2': 1485}
# 2026-05-18 00:03:13,749 [INFO]   [GRAPH] subject_6: building block-diagonal spatial graph
# 2026-05-18 00:03:13,754 [INFO]   [GRAPH] subject_6: adj shape=(3430, 3430), edges=174364
# 2026-05-18 00:03:13,755 [INFO]   -> Run 1/1
# 2026-05-18 00:03:13,758 [INFO]   [TRAIN] Starting STAligner | subject=subject_6 | samples=['SN123_A938797_Rep1_X', 'SN124_A938797_Rep2'] | k_clusters=6 | knn_neigh=50 | device=cuda:0 | run_seed=0
# STAligner(
#   (conv1): GATConv(2858, 512, heads=1)
#   (conv2): GATConv(512, 30, heads=1)
#   (conv3): GATConv(30, 512, heads=1)
#   (conv4): GATConv(512, 2858, heads=1)
# )
# Pretrain with STAGATE...
# 100%|██████████| 500/500 [00:11<00:00, 42.80it/s]
# Train with STAligner...
#   0%|          | 0/500 [00:00<?, ?it/s]
# Update spot triplets at epoch 500
#  20%|█▉        | 99/500 [00:02<00:09, 41.99it/s]
# Update spot triplets at epoch 600
#  40%|███▉      | 198/500 [00:06<00:07, 40.32it/s]
# Update spot triplets at epoch 700
#  59%|█████▉    | 297/500 [00:09<00:05, 39.97it/s]
# Update spot triplets at epoch 800
#  79%|███████▉  | 397/500 [00:12<00:02, 44.08it/s]
# Update spot triplets at epoch 900
# 100%|██████████| 500/500 [00:15<00:00, 32.65it/s]
# 2026-05-18 00:03:41,407 [INFO]   [DIAG] subject_6: STAligner embedding shape=(3430, 30)
# fitting ...
#   |                                                                      |   0%
#   |======================================================================| 100%
# 2026-05-18 00:03:46,619 [INFO]   [DIAG] subject_6: cluster sizes={'1': 553, '2': 497, '3': 506, '4': 924, '5': 331, '6': 619}
# 2026-05-18 00:03:46,646 [INFO]   [METRICS] subject_6/SN123_A938797_Rep1_X: ARI=0.1391  NMI=0.3446  ACC=0.3447  allocated_time=16.4s  subject_time=32.9s  gpu=NVIDIA A30
# 2026-05-18 00:03:46,672 [INFO]   [METRICS] subject_6/SN124_A938797_Rep2: ARI=0.0782  NMI=0.2750  ACC=0.2750  allocated_time=16.4s  subject_time=32.9s  gpu=NVIDIA A30
# 2026-05-18 00:03:46,683 [INFO]
# 2026-05-18 00:03:46,684 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:03:46,685 [INFO] [7/7] Subject group subject_7: ['SN84_A120838_Rep1', 'SN84_A120838_Rep2']
# 2026-05-18 00:03:46,685 [INFO] ------------------------------------------------------------------------
# 2026-05-18 00:03:46,686 [INFO]   [GROUP] Loading subject_7: ['SN84_A120838_Rep1', 'SN84_A120838_Rep2']
# 2026-05-18 00:03:46,686 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN84_A120838_Rep1.h5ad
# 2026-05-18 00:03:46,897 [WARNING]     [READ] SCE_SN84_A120838_Rep1.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:03:46,898 [WARNING]     [READ] SCE_SN84_A120838_Rep1.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:03:46,899 [WARNING]     [READ] SCE_SN84_A120838_Rep1.h5ad: using minimal h5py reader
# 2026-05-18 00:03:46,909 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:03:46,947 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:03:46,948 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(240, 2)
# 2026-05-18 00:03:46,949 [INFO]     [READ] candidate coordinates from /obsm/S: (240, 2)
# 2026-05-18 00:03:46,950 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(240, 2)
# 2026-05-18 00:03:46,954 [INFO]     [DIAG] SN84_A120838_Rep1: n_obs=240, n_vars=36601
# 2026-05-18 00:03:46,955 [INFO]     [DIAG] SN84_A120838_Rep1: obs columns=['z']
# 2026-05-18 00:03:46,955 [INFO]     [DIAG] SN84_A120838_Rep1: obsm keys=['spatial', 'S']
# 2026-05-18 00:03:46,959 [INFO]     [DIAG] SN84_A120838_Rep1: using GT column 'z' (labeled spots: 240/240)
# 2026-05-18 00:03:46,960 [INFO]     [GRAPH] SN84_A120838_Rep1: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 11477 edges, 240 cells.
# 47.8208 neighbors per cell on average.
# 2026-05-18 00:03:47,114 [INFO]     [HVG] SN84_A120838_Rep1: selecting top 5000 genes
# 2026-05-18 00:03:47,190 [INFO]     [DONE] SN84_A120838_Rep1: after HVG/preprocess n_obs=240, n_vars=5000
# 2026-05-18 00:03:47,191 [INFO]     [LOAD] Reading /groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data/SCE_SN84_A120838_Rep2.h5ad
# 2026-05-18 00:03:47,473 [WARNING]     [READ] SCE_SN84_A120838_Rep2.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:03:47,475 [WARNING]     [READ] SCE_SN84_A120838_Rep2.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:03:47,475 [WARNING]     [READ] SCE_SN84_A120838_Rep2.h5ad: using minimal h5py reader
# 2026-05-18 00:03:47,477 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:03:47,595 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:03:47,598 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(853, 2)
# 2026-05-18 00:03:47,599 [INFO]     [READ] candidate coordinates from /obsm/S: (853, 2)
# 2026-05-18 00:03:47,599 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(853, 2)
# 2026-05-18 00:03:47,604 [INFO]     [DIAG] SN84_A120838_Rep2: n_obs=853, n_vars=36601
# 2026-05-18 00:03:47,605 [INFO]     [DIAG] SN84_A120838_Rep2: obs columns=['z']
# 2026-05-18 00:03:47,605 [INFO]     [DIAG] SN84_A120838_Rep2: obsm keys=['spatial', 'S']
# 2026-05-18 00:03:47,609 [INFO]     [DIAG] SN84_A120838_Rep2: using GT column 'z' (labeled spots: 853/853)
# 2026-05-18 00:03:47,610 [INFO]     [GRAPH] SN84_A120838_Rep2: Cal_Spatial_Net(rad_cutoff=150)
# ------Calculating spatial graph...
# The graph contains 42571 edges, 853 cells.
# 49.9074 neighbors per cell on average.
# 2026-05-18 00:03:48,007 [INFO]     [HVG] SN84_A120838_Rep2: selecting top 5000 genes
# 2026-05-18 00:03:48,159 [INFO]     [DONE] SN84_A120838_Rep2: after HVG/preprocess n_obs=853, n_vars=5000
# 2026-05-18 00:03:48,161 [INFO]   [CONCAT] subject_7: concatenating AnnData objects
# 2026-05-18 00:03:48,181 [INFO]   [CONCAT] subject_7: adata_concat shape=(1093, 1916); sample counts={'SN84_A120838_Rep2': 853, 'SN84_A120838_Rep1': 240}
# 2026-05-18 00:03:48,182 [INFO]   [GRAPH] subject_7: building block-diagonal spatial graph
# 2026-05-18 00:03:48,184 [INFO]   [GRAPH] subject_7: adj shape=(1093, 1093), edges=55141
# 2026-05-18 00:03:48,185 [INFO]   -> Run 1/1
# 2026-05-18 00:03:48,186 [INFO]   [TRAIN] Starting STAligner | subject=subject_7 | samples=['SN84_A120838_Rep1', 'SN84_A120838_Rep2'] | k_clusters=6 | knn_neigh=50 | device=cuda:0 | run_seed=0
# STAligner(
#   (conv1): GATConv(1916, 512, heads=1)
#   (conv2): GATConv(512, 30, heads=1)
#   (conv3): GATConv(30, 512, heads=1)
#   (conv4): GATConv(512, 1916, heads=1)
# )
# Pretrain with STAGATE...
# 100%|██████████| 500/500 [00:04<00:00, 119.38it/s]
# Train with STAligner...
#   0%|          | 1/500 [00:00<00:53,  9.41it/s]
# Update spot triplets at epoch 500
#  21%|██        | 105/500 [00:01<00:04, 97.50it/s]
# Update spot triplets at epoch 600
#  42%|████▏     | 209/500 [00:01<00:02, 98.39it/s]
# Update spot triplets at epoch 700
#  63%|██████▎   | 313/500 [00:02<00:01, 98.01it/s]
# Update spot triplets at epoch 800
#  82%|████████▏ | 410/500 [00:03<00:00, 90.06it/s]
# Update spot triplets at epoch 900
# 100%|██████████| 500/500 [00:04<00:00, 109.04it/s]
# 2026-05-18 00:03:57,178 [INFO]   [DIAG] subject_7: STAligner embedding shape=(1093, 30)
# fitting ...
#   |======================================================================| 100%
# 2026-05-18 00:03:59,060 [INFO]   [DIAG] subject_7: cluster sizes={'1': 261, '2': 390, '3': 179, '4': 136, '5': 73, '6': 54}
# 2026-05-18 00:03:59,069 [INFO]   [METRICS] subject_7/SN84_A120838_Rep1: ARI=0.1752  NMI=0.2577  ACC=0.2580  allocated_time=5.4s  subject_time=10.9s  gpu=NVIDIA A30
# 2026-05-18 00:03:59,082 [INFO]   [METRICS] subject_7/SN84_A120838_Rep2: ARI=0.1839  NMI=0.2260  ACC=0.2264  allocated_time=5.4s  subject_time=10.9s  gpu=NVIDIA A30
# 2026-05-18 00:03:59,177 [INFO]
# 2026-05-18 00:03:59,179 [INFO] ========================================================================
# 2026-05-18 00:03:59,179 [INFO] SAVED
# 2026-05-18 00:03:59,180 [INFO] ========================================================================
# 2026-05-18 00:03:59,180 [INFO]   predictions.parquet -> /home/dal875013/work/projects/mocha/results/STAligner/crc_cms_STAligner/predictions.parquet  (19,492 rows)
# 2026-05-18 00:03:59,181 [INFO]   performance.parquet -> /home/dal875013/work/projects/mocha/results/STAligner/crc_cms_STAligner/performance.parquet  (14 rows)
# 2026-05-18 00:03:59,181 [INFO]
# 2026-05-18 00:03:59,182 [INFO] Per-sample metrics:
# 2026-05-18 00:03:59,188 [INFO]
# training_unit               sample      ARI      NMI      ACC  DIS  running_time_sec  subject_running_time_sec
#     subject_1   SN048_A121573_Rep1 0.203401 0.311840 0.311954  NaN             22.06                     44.12
#     subject_1   SN048_A121573_Rep2 0.187368 0.298556 0.298556  NaN             22.06                     44.12
#     subject_2   SN048_A416371_Rep1 0.035834 0.074982 0.075799  NaN             18.02                     36.04
#     subject_2   SN048_A416371_Rep2 0.055344 0.094906 0.096282  NaN             18.02                     36.04
#     subject_3   SN123_A551763_Rep1 0.010823 0.074521 0.078250  NaN              8.95                     17.91
#     subject_3   SN124_A551763_Rep2 0.016396 0.034330 0.036995  NaN              8.95                     17.91
#     subject_4   SN123_A595688_Rep1 0.244361 0.394381 0.396769  NaN              7.12                     14.24
#     subject_4   SN124_A595688_Rep2 0.214038 0.391226 0.391469  NaN              7.12                     14.24
#     subject_5   SN123_A798015_Rep1 0.183628 0.349969 0.350637  NaN             16.52                     33.04
#     subject_5   SN124_A798015_Rep2 0.233690 0.400523 0.401922  NaN             16.52                     33.04
#     subject_6 SN123_A938797_Rep1_X 0.139058 0.344602 0.344693  NaN             16.43                     32.86
#     subject_6   SN124_A938797_Rep2 0.078231 0.274983 0.274995  NaN             16.43                     32.86
#     subject_7    SN84_A120838_Rep1 0.175193 0.257750 0.257965  NaN              5.44                     10.87
#     subject_7    SN84_A120838_Rep2 0.183861 0.226036 0.226442  NaN              5.44                     10.87
# 2026-05-18 00:03:59,189 [INFO]
# 2026-05-18 00:03:59,190 [INFO] Overall mean ARI: 0.1401  NMI: 0.2520  ACC: 0.2531  DIS: nan
# 2026-05-18 00:03:59,191 [INFO] GPU model(s) used: ['NVIDIA A30']
# 2026-05-18 00:03:59,192 [INFO] Total subject-level running time: 189.1s
# 2026-05-18 00:03:59,193 [INFO]
# Benchmarking complete.

# %% [markdown]
# # Prediction results visualization

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
from pathlib import Path

DATA_ROOT  = Path(r"/groups/qiwei/mocha/QuickSRT/CRC_CMS_10x/data")
OUTPUT_DIR = Path(r"/home/dal875013/work/projects/mocha/results/STAligner/crc_cms_STAligner")

SUBJECT_TO_PLOT = "subject_7"

SAMPLES_TO_PLOT = {
    "subject_1": ["SN048_A121573_Rep1", "SN048_A121573_Rep2"],
    "subject_2": ["SN048_A416371_Rep1", "SN048_A416371_Rep2"],
    "subject_3": ["SN123_A551763_Rep1", "SN124_A551763_Rep2"],
    "subject_4": ["SN123_A595688_Rep1", "SN124_A595688_Rep2"],
    "subject_5": ["SN123_A798015_Rep1", "SN124_A798015_Rep2"],
    "subject_6": ["SN123_A938797_Rep1_X", "SN124_A938797_Rep2"],
    "subject_7": ["SN84_A120838_Rep1", "SN84_A120838_Rep2"],
}[SUBJECT_TO_PLOT]

pred_path = OUTPUT_DIR / "predictions.parquet"
if not pred_path.exists():
    raise FileNotFoundError(f"Cannot find {pred_path}. Run the benchmark cell first.")

predictions = pd.read_parquet(pred_path)

fig, axes = plt.subplots(2, len(SAMPLES_TO_PLOT), figsize=(4 * len(SAMPLES_TO_PLOT), 7))
fig.suptitle(f"STAligner CRC_CMS {SUBJECT_TO_PLOT}: Ground Truth vs Cluster Results", fontsize=16)

for j, sample_id in enumerate(SAMPLES_TO_PLOT):
    pred_slice = predictions[predictions["sample"].astype(str) == sample_id].set_index("spot_id")
    adata = read_h5ad_legacy_safe(DATA_ROOT / f"SCE_{sample_id}.h5ad")

    adata.obs["true_label"] = pred_slice["true_label"].reindex(adata.obs_names.astype(str)).values
    adata.obs["pred_label"] = pred_slice["pred_label"].reindex(adata.obs_names.astype(str)).values
    adata.obs["true_label"] = adata.obs["true_label"].astype("category")
    adata.obs["pred_label"] = adata.obs["pred_label"].astype("category")

    if "spatial" not in adata.obsm:
        adata.obsm["spatial"] = np.asarray(adata.obsm["S"])

    sc.pl.embedding(
        adata, basis="spatial", color="true_label",
        ax=axes[0, j], show=False, title=f"{sample_id} — Ground Truth", s=20,
        legend_loc=None,
    )
    sc.pl.embedding(
        adata, basis="spatial", color="pred_label",
        ax=axes[1, j], show=False, title=f"{sample_id} — STAligner", s=20,
        legend_loc=None,
    )
    axes[0, j].invert_yaxis()
    axes[1, j].invert_yaxis()

plt.tight_layout()
plt.show()
# Out:
# 2026-05-18 00:03:59,319 [WARNING]     [READ] SCE_SN84_A120838_Rep1.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:03:59,321 [WARNING]     [READ] SCE_SN84_A120838_Rep1.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:03:59,321 [WARNING]     [READ] SCE_SN84_A120838_Rep1.h5ad: using minimal h5py reader
# 2026-05-18 00:03:59,323 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:03:59,350 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:03:59,352 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(240, 2)
# 2026-05-18 00:03:59,353 [INFO]     [READ] candidate coordinates from /obsm/S: (240, 2)
# 2026-05-18 00:03:59,354 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(240, 2)
# ... storing 'z' as categorical
# 2026-05-18 00:03:59,377 [WARNING]     [READ] SCE_SN84_A120838_Rep2.h5ad: sc.read_h5ad failed in old anndata
# 2026-05-18 00:03:59,378 [WARNING]     [READ] SCE_SN84_A120838_Rep2.h5ad: Above error raised while reading key '/layers' of type <class 'h5py._hl.group.Group'> from /.
# 2026-05-18 00:03:59,379 [WARNING]     [READ] SCE_SN84_A120838_Rep2.h5ad: using minimal h5py reader
# 2026-05-18 00:03:59,381 [INFO]     [READ] HDF5 root keys=['X', 'layers', 'obs', 'obsm', 'obsp', 'uns', 'var', 'varm', 'varp']
# 2026-05-18 00:03:59,424 [INFO]     [READ] HDF5 /obsm keys=['S']
# 2026-05-18 00:03:59,426 [INFO]     [READ] parsed dataframe matrix with columns=['x', 'y']; shape=(853, 2)
# 2026-05-18 00:03:59,427 [INFO]     [READ] candidate coordinates from /obsm/S: (853, 2)
# 2026-05-18 00:03:59,427 [INFO]     [READ] using spatial coordinates from /obsm/S; shape=(853, 2)
# ... storing 'z' as categorical

# %% [markdown]
# # Running results summary

# %%
import pandas as pd
from pathlib import Path

OUTPUT_DIR = Path(r"/home/dal875013/work/projects/mocha/results/STAligner/crc_cms_STAligner")
perf_path = OUTPUT_DIR / "performance.parquet"

if not perf_path.exists():
    raise FileNotFoundError(f"Cannot find {perf_path}")

performance = pd.read_parquet(perf_path)
performance = performance.sort_values(["training_unit", "sample", "run_seed"]).reset_index(drop=True)

display_cols = [
    "training_unit", "sample", "run_seed",
    "ARI", "NMI", "ACC", "DIS",
    "num_clusters", "num_spots", "num_labeled_spots",
    "running_time_sec", "subject_running_time_sec",
    "clust_method", "gpu_model",
]
display_cols = [c for c in display_cols if c in performance.columns]

print("===== All STAligner subject-level CRC_CMS results =====")
display(performance[display_cols])

print("\n===== Summary =====")
summary = performance[["ARI", "NMI", "ACC", "DIS", "running_time_sec"]].describe()
display(summary)

print("\n===== Mean metrics =====")
print(f"Mean ARI: {performance['ARI'].mean():.4f}")
print(f"Mean NMI: {performance['NMI'].mean():.4f}")
print(f"Mean ACC: {performance['ACC'].mean():.4f}")
print(f"Mean DIS: {performance['DIS'].mean():.4f}")

print("\n===== Subject-level runtime =====")
runtime = performance[["training_unit", "run_seed", "subject_running_time_sec"]].drop_duplicates()
display(runtime)
print(f"Total Subject-level runtime: {runtime['subject_running_time_sec'].sum():.2f} sec")

print("\n===== Best / worst ARI =====")
best = performance.loc[performance["ARI"].idxmax()]
worst = performance.loc[performance["ARI"].idxmin()]

print(f"Best ARI : {best['sample']} ({best['training_unit']})  ARI={best['ARI']:.4f}")
print(f"Worst ARI: {worst['sample']} ({worst['training_unit']})  ARI={worst['ARI']:.4f}")
# Out:
# ===== All STAligner subject-level CRC_CMS results =====
#    training_unit                sample  run_seed       ARI       NMI  \
# 0      subject_1    SN048_A121573_Rep1         0  0.203401  0.311840
# 1      subject_1    SN048_A121573_Rep2         0  0.187368  0.298556
# 2      subject_2    SN048_A416371_Rep1         0  0.035834  0.074982
# 3      subject_2    SN048_A416371_Rep2         0  0.055344  0.094906
# 4      subject_3    SN123_A551763_Rep1         0  0.010823  0.074521
# 5      subject_3    SN124_A551763_Rep2         0  0.016396  0.034330
# 6      subject_4    SN123_A595688_Rep1         0  0.244361  0.394381
# 7      subject_4    SN124_A595688_Rep2         0  0.214038  0.391226
# 8      subject_5    SN123_A798015_Rep1         0  0.183628  0.349969
# 9      subject_5    SN124_A798015_Rep2         0  0.233690  0.400523
# 10     subject_6  SN123_A938797_Rep1_X         0  0.139058  0.344602
# 11     subject_6    SN124_A938797_Rep2         0  0.078231  0.274983
# 12     subject_7     SN84_A120838_Rep1         0  0.175193  0.257750
# 13     subject_7     SN84_A120838_Rep2         0  0.183861  0.226036
#
#          ACC  DIS  num_clusters  num_spots  num_labeled_spots  \
# 0   0.311954  NaN             6       2052               2052
# 1   0.298556  NaN             6       2291               2291
# 2   0.075799  NaN             6       2317               2317
# 3   0.096282  NaN             6       1803               1802
# 4   0.078250  NaN             6        665                665
# 5   0.036995  NaN             6       1165               1162
# 6   0.396769  NaN             6       1111               1111
# 7   0.391469  NaN             6        356                356
# 8   0.350637  NaN             6       1635               1609
# 9   0.401922  NaN             6       1574               1478
# 10  0.344693  NaN             6       1945               1944
# 11  0.274995  NaN             6       1485               1485
# 12  0.257965  NaN             6        240                240
# 13  0.226442  NaN             6        853                853
#
#     running_time_sec  subject_running_time_sec clust_method   gpu_model
# 0              22.06                     44.12       mclust  NVIDIA A30
# 1              22.06                     44.12       mclust  NVIDIA A30
# 2              18.02                     36.04       mclust  NVIDIA A30
# 3              18.02                     36.04       mclust  NVIDIA A30
# 4               8.95                     17.91       mclust  NVIDIA A30
# 5               8.95                     17.91       mclust  NVIDIA A30
# 6               7.12                     14.24       mclust  NVIDIA A30
# 7               7.12                     14.24       mclust  NVIDIA A30
# 8              16.52                     33.04       mclust  NVIDIA A30
# 9              16.52                     33.04       mclust  NVIDIA A30
# 10             16.43                     32.86       mclust  NVIDIA A30
# 11             16.43                     32.86       mclust  NVIDIA A30
# 12              5.44                     10.87       mclust  NVIDIA A30
# 13              5.44                     10.87       mclust  NVIDIA A30
# ===== Summary =====
#              ARI        NMI        ACC  DIS  running_time_sec
# count  14.000000  14.000000  14.000000  0.0         14.000000
# mean    0.140088   0.252043   0.253052  NaN         13.505714
# std     0.083333   0.130609   0.130054  NaN          6.048262
# min     0.010823   0.034330   0.036995  NaN          5.440000
# 25%     0.061066   0.127689   0.128822  NaN          7.577500
# 50%     0.179411   0.286769   0.286776  NaN         16.430000
# 75%     0.199392   0.348627   0.349151  NaN         17.645000
# max     0.244361   0.400523   0.401922  NaN         22.060000
# ===== Mean metrics =====
# Mean ARI: 0.1401
# Mean NMI: 0.2520
# Mean ACC: 0.2531
# Mean DIS: nan
#
# ===== Subject-level runtime =====
#    training_unit  run_seed  subject_running_time_sec
# 0      subject_1         0                     44.12
# 2      subject_2         0                     36.04
# 4      subject_3         0                     17.91
# 6      subject_4         0                     14.24
# 8      subject_5         0                     33.04
# 10     subject_6         0                     32.86
# 12     subject_7         0                     10.87
# Total Subject-level runtime: 189.08 sec
#
# ===== Best / worst ARI =====
# Best ARI : SN123_A595688_Rep1 (subject_4)  ARI=0.2444
# Worst ARI: SN123_A551763_Rep1 (subject_3)  ARI=0.0108
